# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Александр, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Итоговый проект Модуля 2: Исследовательский анализ данных пользователей Яндекс.Афиша

# %% [markdown]
# ## Цели и задачи проекта
#
# Цель: провести исследовательский анализ данных, чтобы понять, какие пользователи повторно возвращаются на платформу и делают заказы. Это позволит выявлять перспекивных клиентов, точнее настраивать таргетинг на рекламе, оптимизировать маркетинговые бюджеты
#
# Задачи:
#
# 1. Загрузить и подготовить данные для исследования
# 2. Предобработка данных
# 3. Подготовка профиля пользователя
# 4. Исследовательский анализ
# 5. Корелляционный анализ
# 6. Подготовка выводов и рекомендаций

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Здорово, что оставляешь вводную часть! Она помогает быстро понять цель, контекст и структуру работы, что будет удобно не только для тебя при возвращении к проекту спустя время, но и любому другому читателю (если, например, публикуешь в открытый доступ для портфолио). Воспринимаем эту тетрадку не просто как выполнение домашней работы на курсе, а как полноценный исследовательский проект.
#
# Как правило, в вводную часть включают название проекта, краткое описание цели, используемых данных (источники, объем, особенности), нюансы самого проекта (специфические условия, ограничения, предположения и т.д.). Иногда также сразу обозначают план шагов. Другими словами, вводная часть призвана отразить, что мы делаем, с чем работаем и на каких условиях.
# </div>

# %% [markdown]
# ### 1. Загрузка и подготовка данных для исследования

# %% [markdown]
# #### 1.1 Настройка подключения и выгрузка данных из БД

# %%
# Проводим установку библитотек для работы с SQL
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /Users/mymensk/ya_project/.venv/lib/python3.8/site-packages (2.0.45)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/mymensk/ya_project/.venv/lib/python3.8/site-packages (from sqlalchemy) (4.13.2)

# %%
# Проводим установку адаптера для подключения к базе данных
# !pip install psycopg2 

# Устанавливаем библиотеку для работы с .env

# !pip install python-dotenv
# Out:
# Requirement already satisfied: psycopg2 in /Users/mymensk/ya_project/.venv/lib/python3.8/site-packages (2.9.10)
# Requirement already satisfied: python-dotenv in /Users/mymensk/ya_project/.venv/lib/python3.8/site-packages (1.0.1)
#   Downloading psycopg2-2.9.7.tar.gz (383 kB)
#      |████████████████████████████████| 383 kB 48.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_56d51b6f5cac410699d6e8b23906b1ca/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_56d51b6f5cac410699d6e8b23906b1ca/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-w8v946cr
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_56d51b6f5cac410699d6e8b23906b1ca/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-w8v946cr/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-w8v946cr/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-w8v946cr/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-w8v946cr/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-w8v946cr/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/f7/fa/6e6bb7a7bbe4e02b35aa2fc009fb53221663a5e07e333b72cb5a85e4dbb0/psycopg2-2.9.7.tar.gz#sha256=f00cc35bd7119f1fed17b85bd1007855194dde2cbd8de01ab8ebb17487440ad8 (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.9.6.tar.gz (383 kB)
#      |████████████████████████████████| 383 kB 40.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_3f3af326fd0c4a31ad4ed30dad356134/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_3f3af326fd0c4a31ad4ed30dad356134/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-q_440b_a
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_3f3af326fd0c4a31ad4ed30dad356134/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-q_440b_a/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-q_440b_a/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-q_440b_a/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-q_440b_a/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-q_440b_a/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/af/c4/5726cddb53fe52f0e839eb3da04322364f14493217ebd5818cc5e4c948a5/psycopg2-2.9.6.tar.gz#sha256=f15158418fd826831b28585e2ab48ed8df2d0d98f502a2b4fe619e7d5ca29011 (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.9.5.tar.gz (384 kB)
#      |████████████████████████████████| 384 kB 65.9 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_a1519cc22a994a558737dbb94cd64c7d/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_a1519cc22a994a558737dbb94cd64c7d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-f5ug2two
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_a1519cc22a994a558737dbb94cd64c7d/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-f5ug2two/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-f5ug2two/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-f5ug2two/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-f5ug2two/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-f5ug2two/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/89/d6/cd8c46417e0f7a16b4b0fc321f4ab676a59250d08fce5b64921897fb07cc/psycopg2-2.9.5.tar.gz#sha256=a5246d2e683a972e2187a8714b5c2cf8156c064629f9a9b1a873c1730d9e245a (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.9.4.tar.gz (384 kB)
#      |████████████████████████████████| 384 kB 56.6 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_10e66f693ae74f17a23b434f4b1b62f7/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_10e66f693ae74f17a23b434f4b1b62f7/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-iq5yrgrt
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_10e66f693ae74f17a23b434f4b1b62f7/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-iq5yrgrt/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-iq5yrgrt/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-iq5yrgrt/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-iq5yrgrt/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-iq5yrgrt/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/8d/d7/277e23b708a0429b6b3d50e86e52b791156dfbfa81917d34ef6d7b435b84/psycopg2-2.9.4.tar.gz#sha256=d529926254e093a1b669f692a3aa50069bc71faf5b0ecd91686a78f62767d52f (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.9.3.tar.gz (380 kB)
#      |████████████████████████████████| 380 kB 60.6 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_30bfcd16bb514bb08caf4b276ec5c6b5/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_30bfcd16bb514bb08caf4b276ec5c6b5/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-rsoinuwv
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_30bfcd16bb514bb08caf4b276ec5c6b5/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-rsoinuwv/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-rsoinuwv/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-rsoinuwv/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-rsoinuwv/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-rsoinuwv/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/d1/1e/b450599a27b1809bccbd4e369f397cb18dc56b875778d961f9ae180b54b7/psycopg2-2.9.3.tar.gz#sha256=8e841d1bf3434da985cc5ef13e6f75c8981ced601fd70cc6bf33351b91562981 (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.9.2.tar.gz (380 kB)
#      |████████████████████████████████| 380 kB 40.6 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_ed4fe1b283644da7890e74a314aeb2c7/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_ed4fe1b283644da7890e74a314aeb2c7/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-bl85sdp4
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_ed4fe1b283644da7890e74a314aeb2c7/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-bl85sdp4/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-bl85sdp4/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-bl85sdp4/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-bl85sdp4/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-bl85sdp4/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/33/ed/79434011d773e5ea4c51262f6ebfb86680c2908d7677f31ebccd5aa9f1b3/psycopg2-2.9.2.tar.gz#sha256=a84da9fa891848e0270e8e04dcca073bc9046441eeb47069f5c0e36783debbea (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.9.1.tar.gz (379 kB)
#      |████████████████████████████████| 379 kB 77.3 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_a1c6601d73504c0caa7951f2aac9c42a/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_a1c6601d73504c0caa7951f2aac9c42a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-jpgjeh18
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_a1c6601d73504c0caa7951f2aac9c42a/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-jpgjeh18/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-jpgjeh18/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-jpgjeh18/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-jpgjeh18/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-jpgjeh18/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/aa/8a/7c80e7e44fb1b4277e89bd9ca509aefdd4dd1b2c547c6f293afe9f7ffd04/psycopg2-2.9.1.tar.gz#sha256=de5303a6f1d0a7a34b9d40e4d3bef684ccc44a49bbe3eb85e3c0bffb4a131b7c (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.9.tar.gz (379 kB)
#      |████████████████████████████████| 379 kB 33.8 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_59e23d0cfe88492bbbe16e0ccc61d407/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_59e23d0cfe88492bbbe16e0ccc61d407/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-4q91saax
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_59e23d0cfe88492bbbe16e0ccc61d407/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-4q91saax/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-4q91saax/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-4q91saax/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-4q91saax/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-4q91saax/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6c/79/6df8af2405e2aa60732c47757453fc7fa4af5c90a1796b3392ef892d3a52/psycopg2-2.9.tar.gz#sha256=b12073fdf2002e828e5921be2c39ff9c6eab361c5c0bd6c529619fc23677accc (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.6.tar.gz (383 kB)
#      |████████████████████████████████| 383 kB 66.5 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_0e7cfa1401f142cbae5325a472392906/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_0e7cfa1401f142cbae5325a472392906/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-pco7e0sh
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_0e7cfa1401f142cbae5325a472392906/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-pco7e0sh/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-pco7e0sh/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-pco7e0sh/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-pco7e0sh/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-pco7e0sh/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/fd/ae/98cb7a0cbb1d748ee547b058b14604bd0e9bf285a8e0cc5d148f8a8a952e/psycopg2-2.8.6.tar.gz#sha256=fb23f6c71107c37fd667cb4ea363ddeb936b348bbd6449278eb92c189699f543 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.5.tar.gz (380 kB)
#      |████████████████████████████████| 380 kB 75.7 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_9c77df60bb334dbaac06286c8faba784/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_9c77df60bb334dbaac06286c8faba784/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-_jex0dje
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_9c77df60bb334dbaac06286c8faba784/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-_jex0dje/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-_jex0dje/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-_jex0dje/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-_jex0dje/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-_jex0dje/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a8/8f/1c5690eebf148d1d1554fc00ccf9101e134636553dbb75bdfef4f85d7647/psycopg2-2.8.5.tar.gz#sha256=f7d46240f7a1ae1dd95aab38bd74f7428d46531f69219954266d669da60c0818 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.4.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 67.8 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_fe6d2f13ec524894921591072cd2c1e2/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_fe6d2f13ec524894921591072cd2c1e2/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-i84gdgb_
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_fe6d2f13ec524894921591072cd2c1e2/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-i84gdgb_/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-i84gdgb_/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-i84gdgb_/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-i84gdgb_/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-i84gdgb_/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/84/d7/6a93c99b5ba4d4d22daa3928b983cec66df4536ca50b22ce5dcac65e4e71/psycopg2-2.8.4.tar.gz#sha256=f898e5cc0a662a9e12bde6f931263a1bbd350cfb18e1d5336a12927851825bb6 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.3.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 62.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_6db0c71663264b39b2a2ee2d08a82e92/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_6db0c71663264b39b2a2ee2d08a82e92/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-l0tqewh4
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_6db0c71663264b39b2a2ee2d08a82e92/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-l0tqewh4/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-l0tqewh4/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-l0tqewh4/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-l0tqewh4/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-l0tqewh4/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/1c/6997288da181277a0c29bc39a5f9143ff20b8c99f2a7d059cfb55163e165/psycopg2-2.8.3.tar.gz#sha256=897a6e838319b4bf648a574afb6cabcb17d0488f8c7195100d48d872419f4457 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.2.tar.gz (368 kB)
#      |████████████████████████████████| 368 kB 41.7 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_cc5829aa5498498bb2ab5a79823a9c4d/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_cc5829aa5498498bb2ab5a79823a9c4d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-tbwgxofi
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_cc5829aa5498498bb2ab5a79823a9c4d/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-tbwgxofi/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-tbwgxofi/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-tbwgxofi/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-tbwgxofi/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-tbwgxofi/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/23/7e/93c325482c328619870b6cd09370f6dbe1148283daca65115cd63642e60f/psycopg2-2.8.2.tar.gz#sha256=5cacf21b6f813c239f100ef78a4132056f93a5940219ec25d2ef833cbeb05588 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.1.tar.gz (367 kB)
#      |████████████████████████████████| 367 kB 69.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_a80e2ef9ca74489ca43c3141036f1a3f/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_a80e2ef9ca74489ca43c3141036f1a3f/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-bwfobcz_
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_a80e2ef9ca74489ca43c3141036f1a3f/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-bwfobcz_/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-bwfobcz_/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-bwfobcz_/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-bwfobcz_/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-bwfobcz_/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/52/be/f898e712f5f08131d651a62754fca82a1deb42e4e9889ad01932f770a2be/psycopg2-2.8.1.tar.gz#sha256=b4a475ce87eabc0607e068a3c704d0aa0820237ed78d493b8e2d880eb73cd7fe (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.tar.gz (367 kB)
#      |████████████████████████████████| 367 kB 33.3 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_f1d78e7d4a9e43bd84eea4698710b6c7/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_f1d78e7d4a9e43bd84eea4698710b6c7/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-9iwe9f5h
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_f1d78e7d4a9e43bd84eea4698710b6c7/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-9iwe9f5h/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-9iwe9f5h/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-9iwe9f5h/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-9iwe9f5h/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-9iwe9f5h/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/c7/ca/75236b17f1b951950ffc55d657c5aa408d3d0327a1b6c4c0f7cb16ef7e7b/psycopg2-2.8.tar.gz#sha256=49c5838d90e83217909db3789d30a105385b5e696ec5168cda645546c542f35a (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.7.tar.gz (427 kB)
#      |████████████████████████████████| 427 kB 31.3 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_88d4d86ee1e747cc87a643a294cd1dff/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_88d4d86ee1e747cc87a643a294cd1dff/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-62tcgjfd
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_88d4d86ee1e747cc87a643a294cd1dff/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-62tcgjfd/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-62tcgjfd/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-62tcgjfd/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-62tcgjfd/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-62tcgjfd/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/63/54/c039eb0f46f9a9406b59a638415c2012ad7be9b4b97bfddb1f48c280df3a/psycopg2-2.7.7.tar.gz#sha256=f4526d078aedd5187d0508aa5f9a01eae6a48a470ed678406da94b4cd6524b7e (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.6.1.tar.gz (427 kB)
#      |████████████████████████████████| 427 kB 56.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_11f8aede64fb441d964a16daa970db8a/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_11f8aede64fb441d964a16daa970db8a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-4d6yb6c4
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_11f8aede64fb441d964a16daa970db8a/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-4d6yb6c4/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-4d6yb6c4/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-4d6yb6c4/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-4d6yb6c4/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-4d6yb6c4/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/c0/07/93573b97ed61b6fb907c8439bf58f09957564cf7c39612cef36c547e68c6/psycopg2-2.7.6.1.tar.gz#sha256=27959abe64ca1fc6d8cd11a71a1f421d8287831a3262bd4cacd43bbf43cc3c82 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.6.tar.gz (427 kB)
#      |████████████████████████████████| 427 kB 63.5 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_50408f344d3f43fcb509c1747020daa3/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_50408f344d3f43fcb509c1747020daa3/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-c3v9gyj_
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_50408f344d3f43fcb509c1747020daa3/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-c3v9gyj_/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-c3v9gyj_/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-c3v9gyj_/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-c3v9gyj_/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-c3v9gyj_/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/94/09/2f1fae36d83e2315b90ee91738d01baf8af8c945726bf4b4708fcec3256d/psycopg2-2.7.6.tar.gz#sha256=4a658550b0bcb259e97f77f2dc93ed6b108fe2eda963a9e6fc8b48040d542ec2 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.5.tar.gz (426 kB)
#      |████████████████████████████████| 426 kB 57.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_4b5b0958682a4e629b5b11ba5ff4d4a4/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_4b5b0958682a4e629b5b11ba5ff4d4a4/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-s6mlgrfs
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_4b5b0958682a4e629b5b11ba5ff4d4a4/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-s6mlgrfs/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-s6mlgrfs/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-s6mlgrfs/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-s6mlgrfs/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-s6mlgrfs/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b2/c1/7bf6c464e903ffc4f3f5907c389e5a4199666bf57f6cd6bf46c17912a1f9/psycopg2-2.7.5.tar.gz#sha256=eccf962d41ca46e6326b97c8fe0a6687b58dfc1a5f6540ed071ff1474cea749e (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.4.tar.gz (425 kB)
#      |████████████████████████████████| 425 kB 48.3 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_7f4d6e97acae46bf8fd5fdedb11f9939/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_7f4d6e97acae46bf8fd5fdedb11f9939/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-59pvgb2d
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_7f4d6e97acae46bf8fd5fdedb11f9939/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-59pvgb2d/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-59pvgb2d/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-59pvgb2d/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-59pvgb2d/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-59pvgb2d/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/74/83/51580322ed0e82cba7ad8e0af590b8fb2cf11bd5aaa1ed872661bd36f462/psycopg2-2.7.4.tar.gz#sha256=8bf51191d60f6987482ef0cfe8511bbf4877a5aa7f313d7b488b53189cf26209 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.3.2.tar.gz (425 kB)
# ...
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_8dd757b13bfc47a49ee0cc0dd26ff03a/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_8dd757b13bfc47a49ee0cc0dd26ff03a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-kq0jo891
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_8dd757b13bfc47a49ee0cc0dd26ff03a/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-feszqsrf/psycopg2_8dd757b13bfc47a49ee0cc0dd26ff03a/setup.py", line 247
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/cd/7c/6acf5aacd347f3dc1398eca0e2123c35a48efb07617d4d9578e9cd79a1a7/psycopg2-2.3.1.tar.gz#sha256=7aee74fb13f3b51571fa84cebeeeb29b4230e7553f554f228636c6754752c4e4 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.3.0.tar.gz (588 kB)
#      |████████████████████████████████| 588 kB 46.9 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_93b26a1181854cd4a25bbb9574ad40bf/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_93b26a1181854cd4a25bbb9574ad40bf/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-syxtdcgm
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_93b26a1181854cd4a25bbb9574ad40bf/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-feszqsrf/psycopg2_93b26a1181854cd4a25bbb9574ad40bf/setup.py", line 247
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/68/0a/459df8dcbcc118ca435e9567abceaab919706908d52139e503f6396c4935/psycopg2-2.3.0.tar.gz#sha256=c17a06b7468debba94fa151d3ad93cd885d9cbe9a751e54ceb87738d5f0478ea (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.2.2.tar.gz (530 kB)
#      |████████████████████████████████| 530 kB 56.9 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_d2362478a12a4be98bf3ec86d7d4ae26/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_d2362478a12a4be98bf3ec86d7d4ae26/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-mdny9lzr
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_d2362478a12a4be98bf3ec86d7d4ae26/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-feszqsrf/psycopg2_d2362478a12a4be98bf3ec86d7d4ae26/setup.py", line 245
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/63/3e/a4a35761eb4595fff89e63347b4f8e79c2095782fa5bc016a6dfb18b21ac/psycopg2-2.2.2.tar.gz#sha256=21a33d5b2609103512748098a06249492cc294790e07638fadc68cf06eeac39d (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.2.1.tar.gz (529 kB)
#      |████████████████████████████████| 529 kB 60.0 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_6edc63858ad84438b2a600ba06febbf2/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_6edc63858ad84438b2a600ba06febbf2/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-gx72d5s_
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_6edc63858ad84438b2a600ba06febbf2/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-feszqsrf/psycopg2_6edc63858ad84438b2a600ba06febbf2/setup.py", line 239
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/de/c4/fdfb801035bd7da9e1ce98169d48ca2d6dee5b4361e349afbba40b3d7a5d/psycopg2-2.2.1.tar.gz#sha256=b0eca4e8438025dc57cacbea4e8ca2f5dc0554d41b1cdcc177757a5fc413f3d1 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.2.0.tar.gz (528 kB)
#      |████████████████████████████████| 528 kB 51.7 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_f4e3e301670d42708df17aa85ca13ab2/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_f4e3e301670d42708df17aa85ca13ab2/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-_lowr3zt
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_f4e3e301670d42708df17aa85ca13ab2/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-feszqsrf/psycopg2_f4e3e301670d42708df17aa85ca13ab2/setup.py", line 238
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/32/0c/2f4da04ae2a66d71eff37f19fce67506ad28f887851cd1c1cca35ba08b36/psycopg2-2.2.0.tar.gz#sha256=e70a8eabc491318beef4cd9cd9245a4d8dc62ee31cb74e7988913a66bb33f858 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.14.tar.gz (491 kB)
#      |████████████████████████████████| 491 kB 49.5 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_20cffbe4737b4cc3b8269deb50546eed/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_20cffbe4737b4cc3b8269deb50546eed/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-ndnxn53g
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_20cffbe4737b4cc3b8269deb50546eed/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-feszqsrf/psycopg2_20cffbe4737b4cc3b8269deb50546eed/setup.py", line 238
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/e0/1c/f0843f50a69fba3db880e9b267d36f6709bbf31a36fc46b82f75e8975ede/psycopg2-2.0.14.tar.gz#sha256=902607cdbe1195a00694d2b477eed8429eda433caaa0eb6ff7f80883e1c17ac7 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.13.tar.gz (258 kB)
#      |████████████████████████████████| 258 kB 86.0 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_044274f097ac4d4e95a4767018d356c4/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_044274f097ac4d4e95a4767018d356c4/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-fvrzuc43
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_044274f097ac4d4e95a4767018d356c4/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-feszqsrf/psycopg2_044274f097ac4d4e95a4767018d356c4/setup.py", line 233
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/7a/968afcb86b1958ae963a3aaa42c561e3ed2c2d4a8b773622b03856a16248/psycopg2-2.0.13.tar.gz#sha256=a15e622e101b16aa8ad44813d8fb1eced91379396c054aacbfa3ad658352332b (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.12.tar.gz (256 kB)
#      |████████████████████████████████| 256 kB 60.7 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_cde62696eb8c4754b0fa8e287760c468/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_cde62696eb8c4754b0fa8e287760c468/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-jrnjcblj
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_cde62696eb8c4754b0fa8e287760c468/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-feszqsrf/psycopg2_cde62696eb8c4754b0fa8e287760c468/setup.py", line 225
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6a/8d/ee5c330823d527a5cd14c833063f825211d7b5de6e4897f72e250c107d85/psycopg2-2.0.12.tar.gz#sha256=542c187531e756867fb60034c393b6f2beca34eeeb3ce2e0089a2b6fb8be1292 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.11.tar.gz (255 kB)
#      |████████████████████████████████| 255 kB 43.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_1ca90d2e8f854129868705c81123a42c/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_1ca90d2e8f854129868705c81123a42c/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-4seuw3gj
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_1ca90d2e8f854129868705c81123a42c/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-feszqsrf/psycopg2_1ca90d2e8f854129868705c81123a42c/setup.py", line 225
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2d/d7/496da11d7c81971870ddd36800419c4f84e8f6208aac5eabedf9f7748729/psycopg2-2.0.11.tar.gz#sha256=e6b4e0e41df97441eff34e00065376414da6488e0d55848a45cd77551dbae434 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.10.tar.gz (255 kB)
#      |████████████████████████████████| 255 kB 61.6 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-feszqsrf/psycopg2_55b6bda306fd45b283032bad365c928c/setup.py'"'"'; __file__='"'"'/tmp/pip-install-feszqsrf/psycopg2_55b6bda306fd45b283032bad365c928c/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-8w6x12t8
#          cwd: /tmp/pip-install-feszqsrf/psycopg2_55b6bda306fd45b283032bad365c928c/
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-feszqsrf/psycopg2_55b6bda306fd45b283032bad365c928c/setup.py", line 50, in <module>
#         import ConfigParser
#     ModuleNotFoundError: No module named 'ConfigParser'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/19/79/35c7596bab4456f3610c12ec542a94d51c6781ced587d1d85127210b879b/psycopg2-2.0.10.tar.gz#sha256=e40cc04b43849085725076ae134bfef9e3b087f6dd7c964aeeb930e2f0bc14ab (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement psycopg2 (from versions: 2.0.10, 2.0.11, 2.0.12, 2.0.13, 2.0.14, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.3.2, 2.4, 2.4.1, 2.4.2, 2.4.3, 2.4.4, 2.4.5, 2.4.6, 2.5, 2.5.1, 2.5.2, 2.5.3, 2.5.4, 2.5.5, 2.6, 2.6.1, 2.6.2, 2.7, 2.7.1, 2.7.2, 2.7.3, 2.7.3.1, 2.7.3.2, 2.7.4, 2.7.5, 2.7.6, 2.7.6.1, 2.7.7, 2.8, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.8.5, 2.8.6, 2.9, 2.9.1, 2.9.2, 2.9.3, 2.9.4, 2.9.5, 2.9.6, 2.9.7, 2.9.8, 2.9.9, 2.9.10, 2.9.11)
# ERROR: No matching distribution found for psycopg2

# %%
# Устанавливаем зависимости
# !pip install -i https://test.pypi.org/simple/ psycopg2-binary==2.9.3
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: psycopg2-binary==2.9.3 in /Users/mymensk/ya_project/.venv/lib/python3.8/site-packages (2.9.3)

# %%
# Импортируем pandas - основную библиотеку для анализа и работы с данными
import pandas as pd
from sqlalchemy import create_engine

# %%
# Подключим библиотеки для визуализации: seaborn и matplotlib

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Импортируем библиотеки для работы с файлом окружения
import os
from dotenv import load_dotenv

# %%
# Готовим конфиг для подключения к нужной схеме данных
load_dotenv()
# Out:
# True

# %%
# Указываем маппинг полей конфигурации
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    os.getenv('DB_USER'),
    os.getenv('DB_PASSWORD'),
    os.getenv('DB_HOST'),
    os.getenv('DB_PORT'),
    os.getenv('DB_NAME'),
)

# %%
# Подключаемся к БД с настроенным конфигом
engine = create_engine(connection_string)

# %%
# Определяем запрос, который подготовит нужную выборку данных
query = '''
WITH set_config_precode AS (
  SELECT set_config('synchronize_seqscans', 'off', true)
)
  SELECT ap.user_id,
         ap.device_type_canonical,
         ap.order_id,
         ap.created_dt_msk AS order_dt,
         ap.created_ts_msk AS order_ts,
         ap.currency_code,
         ap.revenue,
         ap.tickets_count,
         (ap.created_dt_msk::date - LAG(ap.created_dt_msk::date) OVER (PARTITION BY ap.user_id ORDER BY ap.created_dt_msk ASC))
         AS days_since_prev,
         ap.event_id,
         ae.event_name_code AS event_name,
         ae.event_type_main,
         ap.service_name,
         ar.region_name,
         ac.city_name
  FROM afisha.purchases AS ap
  LEFT JOIN afisha.events AS ae USING (event_id)
  LEFT JOIN afisha.city AS ac USING (city_id)
  LEFT JOIN afisha.regions AS ar USING (region_id)
  WHERE device_type_canonical IN ('mobile', 'desktop') 
  AND event_type_main != 'фильм'
  ORDER BY ap.user_id ASC
'''

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
#
#
# Сейчас ты явным образом прописываешь параметры подключения к БД. В таком виде выкладывать работу в публичный доступ небезопасно, кто-то сможет завладеть подключением, украсть или повредить данные.
#
# Чтобы засекретить подключение, необходимо сложить все параметры в `.env` файл (или другой конфигурационный файл вне Git) и указать его в `.gitignore`:
#
# ```python
# DB_NAME="..."
# DB_HOST="..."
# DB_PORT="..."
# DB_USER="..."
# DB_PASSWORD="..."
# ```
#
# В самом проекте мы можем обращаться к сохраненным параметрам, для этого нам потребуются библиотеки `dotenv`, чтобы загрузить переменные окружения, и `os`, чтобы обратиться к ним:
#
# ```python
# import os
# import dotenv
#
# load_dotenv() # автоматически ищет .env в текущей директории
#
# connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
#     os.getenv('DB_USER'),
#     os.getenv('DB_PASSWORD'),
#     os.getenv('DB_HOST'),
#     os.getenv('DB_PORT'),
#     os.getenv('DB_NAME'),
# )
# ```
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# На гитхабе так нужно организовать обязательно, для принятия проекта.

# %% [markdown]
# <div class="alert alert-info"> <b>Сделано :)</b> </div>

# %%
# Выгружаем результаты нашего запроса в датафрейм
df = pd.read_sql_query(query, con=engine)

# %%
# Запрашиваем информацию о получившемся датафрейме для подтверждения, что данные успешно выгружены
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
#  14  city_name              290611 non-null  object
# dtypes: datetime64[ns](2), float64(2), int64(3), object(8)
# memory usage: 33.3+ MB

# %% [markdown]
# #### 1.2 Выводы
#
# Данные успешно получены из БД, согласно нашему SQL запросу. Датафрейм состоит из 14 столбцов и 290611 строк. Пропуски данных есть только в столбце days_since_prev - это говорит о том, что не все пользователи делали более 1 заказа и предыдущих заказов у части строк - нет.
# На этапе предобработки заполнять эти пропуски скорее всего не потребуется.
# Можно предположить, что потребуется изменить тип данных у части полей с object на более удобный для работы, например, строки для полей Название города, Регион, Название события

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верно подмечено по поводу пропусков в поле `days_since_prev` (выше пишешь ` может быть всего 1 заказ`), их появление логично объясняется тем, что для некоторых пользователей это их первый заказ, и, соответственно, предыдущей даты для расчёта интервала просто нет.
#
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# На этом этапе стоит предусмотреть проверку на дубликаты, как полные, так и частичные(неявные). Также важно проанализировать категориальные признаки: убедиться, что нет неявных дубликатов из-за различий в регистре, формате записи или опечаток. Числовые столбцы, в свою очередь, нужно проверить на наличие выбросов и некорректных значений.

# %% [markdown]
# ### 2. Предобработка данных

# %% [markdown]
# #### 2.1 Приведение данных к одной валюте

# %%
# Загрузим данные по курсу казахстанского тенге
tenge_df = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')

# %%
# Проверим загруженные данные

tenge_df.info()
tenge_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    object
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 11.3+ KB
#          data  nominal     curs  cdx
# 0  2024-01-10      100  19.9391  kzt
# 1  2024-01-11      100  19.7255  kzt
# 2  2024-01-12      100  19.5839  kzt
# 3  2024-01-13      100  19.4501  kzt
# 4  2024-01-14      100  19.4501  kzt

# %% [markdown]
# В загруженном датафрейме содержатся данные о курсе тенге к рублю в формате: стоимость 100 тенге в рублях на определенную дату.
# Это позволит нам перевести стоимость заказов в тенге в рубли по курсу на дату заказа

# %%
# Для начала необходимо привести столбец data к типу datetime. Напрямую это сделать не получится, потому сначала переведем object -> str,
# а после - str -> datetime

tenge_df['data'] = tenge_df['data'].astype('str')
tenge_df['data'] = pd.to_datetime(tenge_df['data'])
tenge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    datetime64[ns]
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 11.3+ KB

# %%
# Создадим новый объединенный датафрейм, добавив к заказам курсы тенге. Далее проведем перевод тенге в рубли и сохраним в исходный датафрейм

# Отфильтруем заказы в тенге в отдельный датафрейм
kzt_df = df.loc[df['currency_code'] == 'kzt']

# Объединим в один датафрейм с курсом тенге
kztrub_df = kzt_df.merge(tenge_df, left_on='order_dt', right_on='data', how='left')
kztrub_df.info()
kztrub_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5069 entries, 0 to 5068
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                5069 non-null   object
#  1   device_type_canonical  5069 non-null   object
#  2   order_id               5069 non-null   int64
#  3   order_dt               5069 non-null   datetime64[ns]
#  4   order_ts               5069 non-null   datetime64[ns]
#  5   currency_code          5069 non-null   object
#  6   revenue                5069 non-null   float64
#  7   tickets_count          5069 non-null   int64
#  8   days_since_prev        4201 non-null   float64
#  9   event_id               5069 non-null   int64
#  10  event_name             5069 non-null   object
#  11  event_type_main        5069 non-null   object
#  12  service_name           5069 non-null   object
#  13  region_name            5069 non-null   object
#  14  city_name              5069 non-null   object
#  15  data                   5069 non-null   datetime64[ns]
#  16  nominal                5069 non-null   int64
#  17  curs                   5069 non-null   float64
#  18  cdx                    5069 non-null   object
# dtypes: datetime64[ns](3), float64(3), int64(4), object(9)
# memory usage: 752.6+ KB
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0033403583a55ed                mobile   7850214 2024-09-17
# 1  0040e12d70fae81               desktop   8634925 2024-09-02
# 2  0054b38b2653e6e                mobile   7625522 2024-09-09
# 3  00f4f5244501ce6                mobile    720419 2024-06-11
# 4  01370a0e9c1a7d5                mobile   2229811 2024-06-04
#
#              order_ts currency_code   revenue  tickets_count  days_since_prev  \
# 0 2024-09-17 16:52:06           kzt    518.10              4             20.0
# 1 2024-09-02 19:49:14           kzt    347.18              3             39.0
# 2 2024-09-09 18:06:04           kzt    328.77              4              NaN
# 3 2024-06-11 20:15:57           kzt  22021.55              5              NaN
# 4 2024-06-04 13:19:47           kzt   7397.66              4              1.0
#
#    event_id                            event_name event_type_main  \
# 0    559919  f5ec2467-ee48-42f3-89a0-a2d90d1d6fce          другое
# 1    559476  61ec7c0e-ea0c-4a3e-a63a-09cbe1bc6177          другое
# 2    559582  524f434e-0381-4f47-9688-7c4e41961b65          другое
# 3    536826  76af4f88-c554-4e9e-9df4-1cc8aeec8959        концерты
# 4    533803  0686ac7b-6f3e-4177-bb73-16b54acd1223        концерты
#
#          service_name          region_name   city_name       data  nominal  \
# 0  Билеты без проблем  Верхоречная область  Серебрянка 2024-09-17      100
# 1  Билеты без проблем  Верхоречная область  Серебрянка 2024-09-02      100
# 2  Билеты без проблем  Верхоречная область  Серебрянка 2024-09-09      100
# 3           Мой билет  Верхоречная область  Серебрянка 2024-06-11      100
# 4           Мой билет     Шанырский регион   Широковка 2024-06-04      100
#
#       curs  cdx
# 0  19.0125  kzt
# 1  18.9330  kzt
# 2  18.5991  kzt
# 3  19.8928  kzt
# 4  19.9833  kzt

# %%
# Посчитаем стоимость заказов в рублях согласно курсу валют и сохраним в новый столбец
for i in kztrub_df:
    kztrub_df['revenue_rub'] = kztrub_df['revenue'] / 100 * kztrub_df['curs']

# %%
# Проверим полученные данные
kztrub_df.info()
kztrub_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5069 entries, 0 to 5068
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                5069 non-null   object
#  1   device_type_canonical  5069 non-null   object
#  2   order_id               5069 non-null   int64
#  3   order_dt               5069 non-null   datetime64[ns]
#  4   order_ts               5069 non-null   datetime64[ns]
#  5   currency_code          5069 non-null   object
#  6   revenue                5069 non-null   float64
#  7   tickets_count          5069 non-null   int64
#  8   days_since_prev        4201 non-null   float64
#  9   event_id               5069 non-null   int64
#  10  event_name             5069 non-null   object
#  11  event_type_main        5069 non-null   object
#  12  service_name           5069 non-null   object
#  13  region_name            5069 non-null   object
#  14  city_name              5069 non-null   object
#  15  data                   5069 non-null   datetime64[ns]
#  16  nominal                5069 non-null   int64
#  17  curs                   5069 non-null   float64
#  18  cdx                    5069 non-null   object
#  19  revenue_rub            5069 non-null   float64
# dtypes: datetime64[ns](3), float64(4), int64(4), object(9)
# memory usage: 792.2+ KB
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0033403583a55ed                mobile   7850214 2024-09-17
# 1  0040e12d70fae81               desktop   8634925 2024-09-02
# 2  0054b38b2653e6e                mobile   7625522 2024-09-09
# 3  00f4f5244501ce6                mobile    720419 2024-06-11
# 4  01370a0e9c1a7d5                mobile   2229811 2024-06-04
#
#              order_ts currency_code   revenue  tickets_count  days_since_prev  \
# 0 2024-09-17 16:52:06           kzt    518.10              4             20.0
# 1 2024-09-02 19:49:14           kzt    347.18              3             39.0
# 2 2024-09-09 18:06:04           kzt    328.77              4              NaN
# 3 2024-06-11 20:15:57           kzt  22021.55              5              NaN
# 4 2024-06-04 13:19:47           kzt   7397.66              4              1.0
#
#    event_id                            event_name event_type_main  \
# 0    559919  f5ec2467-ee48-42f3-89a0-a2d90d1d6fce          другое
# 1    559476  61ec7c0e-ea0c-4a3e-a63a-09cbe1bc6177          другое
# 2    559582  524f434e-0381-4f47-9688-7c4e41961b65          другое
# 3    536826  76af4f88-c554-4e9e-9df4-1cc8aeec8959        концерты
# 4    533803  0686ac7b-6f3e-4177-bb73-16b54acd1223        концерты
#
#          service_name          region_name   city_name       data  nominal  \
# 0  Билеты без проблем  Верхоречная область  Серебрянка 2024-09-17      100
# 1  Билеты без проблем  Верхоречная область  Серебрянка 2024-09-02      100
# 2  Билеты без проблем  Верхоречная область  Серебрянка 2024-09-09      100
# 3           Мой билет  Верхоречная область  Серебрянка 2024-06-11      100
# 4           Мой билет     Шанырский регион   Широковка 2024-06-04      100
#
#       curs  cdx  revenue_rub
# 0  19.0125  kzt    98.503762
# 1  18.9330  kzt    65.731589
# 2  18.5991  kzt    61.148261
# 3  19.8928  kzt  4380.702898
# 4  19.9833  kzt  1478.296591

# %%
# Теперь нужно добавить полученное значение в исходный датафрейм. Для этого выделим столбцы order_id и revenue_rub и добавим их в 
# исходный датафрейм

transfer_df = kztrub_df[['order_id', 'revenue_rub']]
transfer_df.info()

df = df.merge(transfer_df, how='left', on='order_id')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5069 entries, 0 to 5068
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     5069 non-null   int64
#  1   revenue_rub  5069 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 79.3 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
#  14  city_name              290611 non-null  object
#  15  revenue_rub            5069 non-null    float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(8)
# memory usage: 35.5+ MB

# %%
# Пройдем в цикле все строки датафрейма и заполним пустые значения revenue_rub значениями revenue
for i in df:
    df['revenue_rub'] = df['revenue_rub'].fillna(df['revenue'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
#  14  city_name              290611 non-null  object
#  15  revenue_rub            290611 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(8)
# memory usage: 35.5+ MB

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С шагом справились, результат корректный! Хорошо, что убеждаешься в этом.
# </div>
#
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * При подгрузке любых данных тоит сперва убедиться, что они корректны, данные о курсе не исключение. Тогда бы мы как раз могли обосновать, что требуется корректировка типа данных для даты. Сейчас по сути этот шаг берется из ниоткуда.
#
#
# * Существует довольно удобный метод [where](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.where.html). Мы можем применить его к столбцу и указать условие, которое будем проверять, а также альтернативный вариант значения. Если условие выполняется, то берется значение из столбца, если нет - альтернативное значение. Тогда расчет выручки в рублях будет выглядеть следующим образом:
#
#     ```python
# df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs'] / 100)
# ```
#
#
#
# * Не забываем фиксировать в выводах наши промежуточные наблюдения (например, что все прошло хорошо, теперь выручка скорректирована, и ее можно использовать для дальнейшего анализа).
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> Я решил сделать работу, используя только то, что было в курсе. Про Where не знал :)</div>

# %% [markdown]
# #### 2.2 Проверка на пропуски, формат и тип данных. Фильтрация

# %% [markdown]
# Пропуски данных присутствуют только в days_since_prev.
#
# Можно преобразовать тип данных в поле days_since_prev в int. Также можно сократить размерность данных в столбцах:
# order_id до int32,
# days_since_prev до float32,
# tickets_count до int8,
# event_id до int32

# %%
# Проведем нужные преобразования и проверим датафрейм

df['days_since_prev'] = pd.to_numeric(df['days_since_prev'], downcast='float')
df['order_id'] = pd.to_numeric(df['order_id'], downcast='integer')
df['tickets_count'] = pd.to_numeric(df['tickets_count'], downcast='integer')
df['event_id'] = pd.to_numeric(df['event_id'], downcast='integer')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int32
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int8
#  8   days_since_prev        268678 non-null  float32
#  9   event_id               290611 non-null  int32
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
#  14  city_name              290611 non-null  object
#  15  revenue_rub            290611 non-null  float64
# dtypes: datetime64[ns](2), float32(1), float64(2), int32(2), int8(1), object(8)
# memory usage: 30.2+ MB

# %%
# Выведем количество уникальных значений по столбцам

df.nunique()
# Out:
# user_id                   21933
# device_type_canonical         2
# order_id                 290611
# order_dt                    153
# order_ts                 280753
# currency_code                 2
# revenue                   42522
# tickets_count                22
# days_since_prev             149
# event_id                  22427
# event_name                15248
# event_type_main               7
# service_name                 36
# region_name                  81
# city_name                   352
# revenue_rub               43691
# dtype: int64

# %%
# Выведем уникальные значения по номинальным данным

df['device_type_canonical'].unique()
# Out:
# array(['mobile', 'desktop'], dtype=object)

# %%
df['event_type_main'].unique()
# Out:
# array(['театр', 'выставки', 'другое', 'стендап', 'концерты', 'спорт',
#        'ёлки'], dtype=object)

# %%
# Проведем исследование распределения численных данных и выбросов в них. Нас интересуют поля: revenue_rub и tickets_count

df['revenue_rub'].describe()
# Out:
# count    290611.000000
# mean        555.571987
# std         875.498172
# min         -90.760000
# 25%         113.970000
# 50%         351.140000
# 75%         802.050000
# max       81174.540000
# Name: revenue_rub, dtype: float64

# %%
df['tickets_count'].describe()
# Out:
# count    290611.000000
# mean          2.754311
# std           1.170620
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          57.000000
# Name: tickets_count, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Все необходимые библиотеки стоит выгружать в начале проекта в одной ячейке кода. Чтобы сразу видеть, какие модули используются в проекте

# %% [markdown]
# <div class="alert alert-info"> Перенес в начало </div>

# %%
# Построим диаграммы размаха и гистограммы распределения по интересующим полям

plot1 = df.boxplot(column='revenue_rub',
           vert=False,
           grid=True,
           figsize=(12, 10))

plot1.set_title('Распределение выручки по заказам, руб')
plt.show()

# %%
plot2 = df.boxplot(column='tickets_count',
           vert=False,
           grid=True,
           figsize=(12, 10))

plot2.set_title('Распределение количества билетов в заказах, шт')
plt.show()

# %%
sns.histplot(data=df, x='revenue_rub', bins=40, kde=True)

plt.title('Гистограмма распределения выручки по заказам')
plt.xlabel('Выручка, руб')
plt.ylabel('Количество заказов, шт')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# График по данным построен корректно, но не оформлен до конца. Суть в том, что график должен быть наглядным без контекста (т.к. в реальной практике ты будешь показывать презентации или отчет сторонним людям).
#
# Тебе необходимо проследить чтобы всегда был заголовок и подписаны оси. Доработай этот момент пожалуйста.
#
# Данное замечания относится ко всему проекту и перепроверь его самостоятельно. Далее не буду акцентировать на этом внимание

# %% [markdown]
# <div class="alert alert-info"> Исправился </div>

# %%
sns.histplot(data=df, x='tickets_count', bins=40, kde=True)
plt.title('Гистограмма распределения числа билетов в заказах')
plt.xlabel('Число билетов на заказ, шт')
plt.ylabel('Количество заказов, шт')
plt.show()

# %% [markdown]
# Оба поля содержат выбросы, в поле revenue_rub также присутствуют аномальные значения (отрицательные). Для получения более качественных данных
# необходимо отфильтровать revenue_rub по значениям выше нуля, и также по 99% персентилю, чтобы исключить аномальные выбросы.
#
# По полю tickets_count отрицательных значений нет, потому также отфильтруем значения по 99% персентилю, чтобы исключить из расчетов аномальные выбросы (заказы с аномально большим количеством билетов)

# %%
# Находим 99 персентиль по полю revenue_rub

pers99_rev = df['revenue_rub'].quantile(0.99)
pers99_rev_tickets = df['tickets_count'].quantile(0.99)

# Фильтруем данные по значению 99 персентиля  и выше 0

filtered_df = df.loc[(df['revenue_rub']<pers99_rev) & (df['revenue_rub']>0)& (df['tickets_count']<pers99_rev_tickets)]

# Проверяем

filtered_df.info()

# Количество отфильтрованных строк
print(f'В результате фильтрации выборка уменьшена на: {df.shape[0] - filtered_df.shape[0]} строк, что составляет {round((df.shape[0] - filtered_df.shape[0]) / df.shape[0] * 100, 1)} %' )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 277603 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                277603 non-null  object
#  1   device_type_canonical  277603 non-null  object
#  2   order_id               277603 non-null  int32
#  3   order_dt               277603 non-null  datetime64[ns]
#  4   order_ts               277603 non-null  datetime64[ns]
#  5   currency_code          277603 non-null  object
#  6   revenue                277603 non-null  float64
#  7   tickets_count          277603 non-null  int8
#  8   days_since_prev        256540 non-null  float32
#  9   event_id               277603 non-null  int32
#  10  event_name             277603 non-null  object
#  11  event_type_main        277603 non-null  object
#  12  service_name           277603 non-null  object
#  13  region_name            277603 non-null  object
#  14  city_name              277603 non-null  object
#  15  revenue_rub            277603 non-null  float64
# dtypes: datetime64[ns](2), float32(1), float64(2), int32(2), int8(1), object(8)
# memory usage: 31.0+ MB
# В результате фильтрации выборка уменьшена на: 13008 строк, что составляет 4.5 %

# %%
# Проверим категориальные признаки на предмет аномалий, выбросов и дубликатов

print(f"Категории мероприятий: {filtered_df['event_type_main'].unique()}")
filtered_df.groupby('event_type_main')['order_id'].count()
# Out:
# Категории мероприятий: ['театр' 'выставки' 'другое' 'стендап' 'концерты' 'ёлки' 'спорт']
# event_type_main
# выставки      4783
# другое       59859
# концерты    111495
# спорт        20966
# стендап      13017
# театр        65583
# ёлки          1900
# Name: order_id, dtype: int64

# %% [markdown]
# По категориям мероприятий аномалий нет: все категории названы корректно, распределение по категориям - корректное. Елки - самая редкая категория заказов, что связано с небольшим сезонностью

# %%
# Исследуем на дубликаты название мероприятий, регионов и городов

data_duplicates = filtered_df[filtered_df.duplicated(subset=['user_id', 'device_type_canonical', 'order_dt', 'tickets_count', 'revenue_rub', 'event_type_main', 'event_name', 'region_name', 'city_name', 'service_name'], keep='first')]
print("\nДубликаты по ID пользователя, устройству, дате заказа, числу билетов, выручке, названию и типу мероприятий, региону, городу и названию билетного оператора:")
print(data_duplicates.count())
# Out:
# Дубликаты по ID пользователя, устройству, дате заказа, числу билетов, выручке, названию и типу мероприятий, региону, городу и названию билетного оператора:
# user_id                  48303
# device_type_canonical    48303
# order_id                 48303
# order_dt                 48303
# order_ts                 48303
# currency_code            48303
# revenue                  48303
# tickets_count            48303
# days_since_prev          48303
# event_id                 48303
# event_name               48303
# event_type_main          48303
# service_name             48303
# region_name              48303
# city_name                48303
# revenue_rub              48303
# dtype: int64

# %%
# Подобные дубликаты необходимо удалить, заказы задублировались, создались с разным временем заказа. Оставим только первое вхождение

filtered_df = filtered_df.drop_duplicates(subset=['user_id', 'device_type_canonical', 'order_dt', 'tickets_count', 'revenue_rub', 'event_type_main', 'event_name', 'region_name', 'city_name', 'service_name'], keep='first')

# Проверяем

filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229300 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                229300 non-null  object
#  1   device_type_canonical  229300 non-null  object
#  2   order_id               229300 non-null  int32
#  3   order_dt               229300 non-null  datetime64[ns]
#  4   order_ts               229300 non-null  datetime64[ns]
#  5   currency_code          229300 non-null  object
#  6   revenue                229300 non-null  float64
#  7   tickets_count          229300 non-null  int8
#  8   days_since_prev        208237 non-null  float32
#  9   event_id               229300 non-null  int32
#  10  event_name             229300 non-null  object
#  11  event_type_main        229300 non-null  object
#  12  service_name           229300 non-null  object
#  13  region_name            229300 non-null  object
#  14  city_name              229300 non-null  object
#  15  revenue_rub            229300 non-null  float64
# dtypes: datetime64[ns](2), float32(1), float64(2), int32(2), int8(1), object(8)
# memory usage: 25.6+ MB

# %%
print(f'В результате удаления дубликатов выборка уменьшена на: {df.shape[0] - filtered_df.shape[0]} строк, что составляет {round((df.shape[0] - filtered_df.shape[0]) / df.shape[0] * 100, 1)} %' )
# Out:
# В результате удаления дубликатов выборка уменьшена на: 61311 строк, что составляет 21.1 %

# %% [markdown]
# ### Выводы
#
# В рамках подготовки и предобработки данных были проведены операции:
# 1. Уменьшена размерность некоторых столбцов для оптимизации использования памяти
# 2. Стоимость заказов приведена к единой валюте - Рубль РФ, создан новый столбец revenue_rub, в котором хранится выручка в единой валюте
# 3. Проведена фильтрация данных по аномальным выбросам по выручке (отрицательные значения и выбросы по 99 персентилю).
# 4. Проведено удаление дубликатов заказов.
# 5. Количество удалено строк - 61311 строк, что составляет 21.1 %

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# * Сейчас ты фиксируешь общие выводы только в конце раздела. Чтобы в работе был понятный сторителлинг, стоит также фиксировать промежуточные свои наблюдения для каждого из шагов: почему мы ничего не стали делать с пропусками и перешли к следующему шагу? Как приняли решение скорректировать тип у тех или иных столбцов? Действительно ли наши категориальные признаки в порядке и не требуют нормализации? Действительно ли в числовых признаках есть выбросы, какова их предполагаемая природа возникновения? Почему мы решили отбросить выбросы в выручке? Почему решили не отбрасывать выбросы в количестве билетов?
#
#
# * Для удобства анализа гистограмму для определенного признака стоит строить рядом с боксплотом, чтобы можно было сопоставлять информацию из них. Можно даже создать пользовательскую функцию, которая будет принимать на вход признак и выводить для него сразу два типа визуализации в одном графике ([пример](https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/)).
#
#
#
# </div>
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
#
#
# * В задании это не указывается, но по умолчанию важным шагом предварительного анализа и предобработки является проверка на наличие дубликатов, как полных, так и неполных (например, если заказ пользователя задублировался в системе, был создан в нескольких экземплярах с разным `id` и временем заказа). Чтобы не искажать статистические расчеты, от таких наблюдений тоже важно избавляться.
#
#
# * Не изучены категориальные признаки. Тут я бы рекомендовал более тщательнее следить за чистотой данных, проверить категориальные признаки на предмет аномалий и сследить за распределением данных по признакам. Так можно сразу отловить категории с небольшим количеством данных
#
#         # Анализ категориальных значений
#         for column in ['columnname', 'columnname', 'columnname', 'columnname']:
#         print(f"\nColumn: {column}")
#         print("Unique values:", df[column].unique())
#         print("Missing values count:", df[column].isna().sum())
#         print("Value counts:")
#         print(df[column].value_counts(dropna=False), "\n")
#
#
# </div>
#
# <div class="alert alert-info"> Короткое пояснение, почему так (убрал выбросы в стоимости заказов и не стал в билетах) - есть сразу после графиков </div>
#
# <div class="alert alert-info"> Дубликаты удалены </div>

# %% [markdown]
# ### 3. Создание профиля пользователя

# %% [markdown]
# #### 3.1 Построить профиль пользователя

# %%
# Отсортируем наш датафрейм по дате совершения заказов по возрастанию даты

sorted_df = filtered_df.sort_values(by='order_dt')
sorted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229300 entries, 144800 to 209784
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                229300 non-null  object
#  1   device_type_canonical  229300 non-null  object
#  2   order_id               229300 non-null  int32
#  3   order_dt               229300 non-null  datetime64[ns]
#  4   order_ts               229300 non-null  datetime64[ns]
#  5   currency_code          229300 non-null  object
#  6   revenue                229300 non-null  float64
#  7   tickets_count          229300 non-null  int8
#  8   days_since_prev        208237 non-null  float32
#  9   event_id               229300 non-null  int32
#  10  event_name             229300 non-null  object
#  11  event_type_main        229300 non-null  object
#  12  service_name           229300 non-null  object
#  13  region_name            229300 non-null  object
#  14  city_name              229300 non-null  object
#  15  revenue_rub            229300 non-null  float64
# dtypes: datetime64[ns](2), float32(1), float64(2), int32(2), int8(1), object(8)
# memory usage: 25.6+ MB

# %%
profile_df = sorted_df.groupby('user_id').agg(
    first_order=('order_dt', 'min'),
    last_order=('order_dt', 'max'),
    orders_count=('order_id', 'count'),
    avg_revenue=('revenue_rub', 'mean'),
    avg_tickets=('tickets_count', 'mean'),
    avg_days_between=('days_since_prev', 'mean')
).reset_index()

# %%
profile_df.info()
profile_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21551 entries, 0 to 21550
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           21551 non-null  object
#  1   first_order       21551 non-null  datetime64[ns]
#  2   last_order        21551 non-null  datetime64[ns]
#  3   orders_count      21551 non-null  int64
#  4   avg_revenue       21551 non-null  float64
#  5   avg_tickets       21551 non-null  float64
#  6   avg_days_between  12859 non-null  float32
# dtypes: datetime64[ns](2), float32(1), float64(2), int64(1), object(1)
# memory usage: 1.1+ MB
#            user_id first_order last_order  orders_count  avg_revenue  \
# 0  0002849b70a3ce2  2024-08-20 2024-08-20             1  1521.940000
# 1  0005ca5e93f2cf4  2024-07-23 2024-10-06             2   774.010000
# 2  000898990054619  2024-07-13 2024-10-23             3   767.213333
# 3  00096d1f542ab2b  2024-08-15 2024-08-15             1   917.830000
# 4  000a55a418c128c  2024-09-29 2024-10-15             2    61.310000
#
#    avg_tickets  avg_days_between
# 0     4.000000               NaN
# 1     3.000000              75.0
# 2     2.666667              51.0
# 3     4.000000               NaN
# 4     1.500000              16.0

# %%
# Теперь выберем дополнительные данные по каждому пользователю, используя сортировку по user_id и дате заказа. Удалим все данные по каждому,
# кроме первой записи. Оставим только нужные нам столбцы
additional_data = sorted_df.sort_values(['user_id', 
                                         'order_dt']).drop_duplicates('user_id')[['user_id',
                                                                                  'device_type_canonical', 
                                                                                  'region_name', 
                                                                                  'service_name', 
                                                                                  'event_type_main']]

# %%
# Проверяем получившийся датафрейм
additional_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21551 entries, 0 to 290610
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                21551 non-null  object
#  1   device_type_canonical  21551 non-null  object
#  2   region_name            21551 non-null  object
#  3   service_name           21551 non-null  object
#  4   event_type_main        21551 non-null  object
# dtypes: object(5)
# memory usage: 1010.2+ KB

# %%
# Добавляем данные в датафрейм с профилем заказов пользователя

profile_df = profile_df.merge(additional_data, on='user_id')

# %%
# Проверяем

profile_df.info()
profile_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21551 entries, 0 to 21550
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                21551 non-null  object
#  1   first_order            21551 non-null  datetime64[ns]
#  2   last_order             21551 non-null  datetime64[ns]
#  3   orders_count           21551 non-null  int64
#  4   avg_revenue            21551 non-null  float64
#  5   avg_tickets            21551 non-null  float64
#  6   avg_days_between       12859 non-null  float32
#  7   device_type_canonical  21551 non-null  object
#  8   region_name            21551 non-null  object
#  9   service_name           21551 non-null  object
#  10  event_type_main        21551 non-null  object
# dtypes: datetime64[ns](2), float32(1), float64(2), int64(1), object(5)
# memory usage: 1.7+ MB
#            user_id first_order last_order  orders_count  avg_revenue  \
# 0  0002849b70a3ce2  2024-08-20 2024-08-20             1  1521.940000
# 1  0005ca5e93f2cf4  2024-07-23 2024-10-06             2   774.010000
# 2  000898990054619  2024-07-13 2024-10-23             3   767.213333
# 3  00096d1f542ab2b  2024-08-15 2024-08-15             1   917.830000
# 4  000a55a418c128c  2024-09-29 2024-10-15             2    61.310000
#
#    avg_tickets  avg_days_between device_type_canonical           region_name  \
# 0     4.000000               NaN                mobile    Каменевский регион
# 1     3.000000              75.0                mobile    Каменевский регион
# 2     2.666667              51.0                mobile  Североярская область
# 3     4.000000               NaN               desktop    Каменевский регион
# 4     1.500000              16.0                mobile      Поленовский край
#
#     service_name event_type_main
# 0   Край билетов           театр
# 1      Мой билет        выставки
# 2    Лови билет!          другое
# 3   Край билетов           театр
# 4  Лучшие билеты           театр

# %%
# Добавим два новых признака: is_two и is_five

profile_df['is_five'] = profile_df['orders_count'] >= 5
profile_df['is_two'] = profile_df['orders_count'] >= 2

# %%
# Проверяем

profile_df.info()
profile_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21551 entries, 0 to 21550
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                21551 non-null  object
#  1   first_order            21551 non-null  datetime64[ns]
#  2   last_order             21551 non-null  datetime64[ns]
#  3   orders_count           21551 non-null  int64
#  4   avg_revenue            21551 non-null  float64
#  5   avg_tickets            21551 non-null  float64
#  6   avg_days_between       12859 non-null  float32
#  7   device_type_canonical  21551 non-null  object
#  8   region_name            21551 non-null  object
#  9   service_name           21551 non-null  object
#  10  event_type_main        21551 non-null  object
#  11  is_five                21551 non-null  bool
#  12  is_two                 21551 non-null  bool
# dtypes: bool(2), datetime64[ns](2), float32(1), float64(2), int64(1), object(5)
# memory usage: 1.8+ MB
#            user_id first_order last_order  orders_count  avg_revenue  \
# 0  0002849b70a3ce2  2024-08-20 2024-08-20             1  1521.940000
# 1  0005ca5e93f2cf4  2024-07-23 2024-10-06             2   774.010000
# 2  000898990054619  2024-07-13 2024-10-23             3   767.213333
# 3  00096d1f542ab2b  2024-08-15 2024-08-15             1   917.830000
# 4  000a55a418c128c  2024-09-29 2024-10-15             2    61.310000
#
#    avg_tickets  avg_days_between device_type_canonical           region_name  \
# 0     4.000000               NaN                mobile    Каменевский регион
# 1     3.000000              75.0                mobile    Каменевский регион
# 2     2.666667              51.0                mobile  Североярская область
# 3     4.000000               NaN               desktop    Каменевский регион
# 4     1.500000              16.0                mobile      Поленовский край
#
#     service_name event_type_main  is_five  is_two
# 0   Край билетов           театр    False   False
# 1      Мой билет        выставки    False    True
# 2    Лови билет!          другое    False    True
# 3   Край билетов           театр    False   False
# 4  Лучшие билеты           театр    False    True

# %%
# Отдельно использовал функционал выделения профиля пользователя из комментария для сравнения 

profiles = (filtered_df
        # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
        .sort_values(by='order_ts')
        # Затем группируем по номеру пользователя и агрегируем данные:
        .groupby('user_id')
        .agg(
            # Находим первую и последнюю даты заказа:
            first_order_dt=('order_dt','min'),
            last_order_dt=('order_dt','max'),
            # Находим устройства, регион, название билетного партнера и тип мероприятия первого заказа:
            first_device=('device_type_canonical','first'),
            first_region_name=('region_name','first'),
            first_service_name=('service_name','first'),
            first_event_type=('event_type_main','first'),
            # Подсчитваем количество заказов:
            total_orders=('order_id','nunique'),
            # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
            avg_revenue_rub=('revenue_rub','mean'),
            avg_tickets_count=('tickets_count','mean'),
            # Считаем среднее количество дней между покупками:
            avg_days_since_prev=('days_since_prev','mean')
        )
        # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
        .assign(
            is_two = lambda x: x['total_orders'] >= 2,
            is_five = lambda x: x['total_orders'] >= 5
        )
        .reset_index()
)

profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21551 entries, 0 to 21550
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              21551 non-null  object
#  1   first_order_dt       21551 non-null  datetime64[ns]
#  2   last_order_dt        21551 non-null  datetime64[ns]
#  3   first_device         21551 non-null  object
#  4   first_region_name    21551 non-null  object
#  5   first_service_name   21551 non-null  object
#  6   first_event_type     21551 non-null  object
#  7   total_orders         21551 non-null  int64
#  8   avg_revenue_rub      21551 non-null  float64
#  9   avg_tickets_count    21551 non-null  float64
#  10  avg_days_since_prev  12859 non-null  float32
#  11  is_two               21551 non-null  bool
#  12  is_five              21551 non-null  bool
# dtypes: bool(2), datetime64[ns](2), float32(1), float64(2), int64(1), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Твой способ определения значений категориальных характеристик первого заказа не надежен. Если у пользователя было несколько заказов в первый день, присоединение значений по дате приведет к дублированию записей о пользователе.
#
# В данном случае необходимо группировать и использовать метод агрегации `first`, он берет значение первой записи. Как раз ввиду его использования и следовало отсортировать заказы по времени.
#
# Обрати внимание, что с учетом данной правки могут потребоваться и корректировки в шагах ниже.
#
# </div>
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Также есть довольно удобный метод [assign](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html), позволяющий дополнять таблицу новыми рассчитанными столбцами.
#
#     Тогда создание всего профиля можно будет записать красивым и удобным по структуре кодом.
#
#     <details> <summary> <span style='color:blue' > Развернуть подробнее. </span> </summary>
#
#     ```python
#     profiles = (df
#             # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
#             .sort_values(by='order_ts')
#             # Затем группируем по номеру пользователя и агрегируем данные:
#             .groupby('user_id')
#             .agg(
#                 # Находим первую и последнюю даты заказа:
#                 first_order_dt=('order_dt','min'),
#                 last_order_dt=('order_dt','max'),
#                 # Находим устройства, регион, название билетного партнера и тип мероприятия первого заказа:
#                 first_device=('device_type_canonical','first'),
#                 first_region_name=('region_name','first'),
#                 first_service_name=('service_name','first'),
#                 first_event_type=('event_type_main','first'),
#                 # Подсчитваем количество заказов:
#                 total_orders=('order_id','nunique'),
#                 # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
#                 avg_revenue_rub=('revenue_rub','mean'),
#                 avg_tickets_count=('tickets_count','mean'),
#                 # Считаем среднее количество дней между покупками:
#                 avg_days_since_prev=('days_since_prev','mean')
#             )
#             # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
#             .assign(
#                 is_two = lambda x: x['total_orders'] >= 2,
#                 is_five = lambda x: x['total_orders'] >= 5
#             )
#             .reset_index()
#     )
#     ```
#     </details>
#
#
# * Согласно стандартам оформления кода не стоит делать строики длиной более 79 символов, это портит его читаемость, вынуждает прокручивать ячейку (внимание на 35 ячейку)
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> Я делал пошагово, используя те методы, которые были в курсе. Возможно, изучение нового достаточно полезная история :) Но функцию first и использование lambda x не изучал. Специально, в отдельной ячейке посчитал profiles твоим методом и вывел info - количество строк по всем полям совпадает с моим. Потому далее использовал свой датафрейм </div>

# %% [markdown]
# #### 3.2 Изучение данных на предмет готовности к исследовательскому анализу

# %% [markdown]
# Рассчитаем ряд статистических показателей, чтобы оценить выборку:
# 1. Общее число пользователей
# 2. Среднюю выручку с заказа
# 3. Долю пользователей с 2 и более заказами
# 4. Долю пользователей с 5 и более заказами

# %%
# Всего пользователей

user_number = profile_df['user_id'].nunique()
print(f'Всего уникальных пользователей в выборке: {user_number}')
# Out:
# Всего уникальных пользователей в выборке: 21551

# %%
avg_revenue_all = round(profile_df['avg_revenue'].mean(),2)
print(f'Средняя выручка за один заказ по всей выборке: {avg_revenue_all} RUB')
# Out:
# Средняя выручка за один заказ по всей выборке: 546.3 RUB

# %%
is_two_share = round(profile_df['is_two'].sum() / profile_df.shape[0] * 100, 2)
print(f'Доля пользователей с двумя и более заказами: {is_two_share} %')
# Out:
# Доля пользователей с двумя и более заказами: 59.1 %

# %%
is_five_share = round(profile_df['is_five'].sum() / profile_df.shape[0] * 100, 2)
print(f'Доля пользователей с пятью и более заказами: {is_five_share} %')
# Out:
# Доля пользователей с пятью и более заказами: 24.75 %

# %% [markdown]
# Дополнительно посчитаем:
# 1. Общее число заказов
# 2. Среднее число билетов в заказе
# 3. Среднее количество дней между покупками

# %%
orders_count_all = profile_df['orders_count'].sum()
print(f'Всего заказов в выборке: {orders_count_all}')
# Out:
# Всего заказов в выборке: 229300

# %%
avg_tickets_all = round(profile_df['avg_tickets'].mean(), 2)
print(f'Среднее число билетов по выборке: {avg_tickets_all}')
# Out:
# Среднее число билетов по выборке: 2.7

# %%
avg_days_between_all = profile_df['avg_days_between'].mean()
avg_days_between_all = round(avg_days_between_all, 2)
print(f'Среднее число дней между заказами: {avg_days_between_all}')
# Out:
# Среднее число дней между заказами: 18.229999542236328

# %%
# Изучим статистику по числу заказов на пользователя
profile_df['orders_count'].describe()
# Out:
# count    21551.000000
# mean        10.639877
# std         98.741194
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max       8375.000000
# Name: orders_count, dtype: float64

# %%
# Построим диаграмму распределения, потому что максимальное число заказов аномально большое, и необходимо дополнительно изучить выбросы

plot3 = profile_df.boxplot(column='orders_count',
                           vert=False,
                           grid=True,
                           figsize=(12, 10))

plot3.set_title('Распределение количества заказов по пользователям, шт')
plt.show()

# %%
# Рассчитаем 95% персентиль по числу заказов

order_count_95pers = profile_df['orders_count'].quantile(0.95)
print(f'В 95 персентиль попадает число: {order_count_95pers}')
# Out:
# В 95 персентиль попадает число: 25.0

# %%
# Для более качественного исследования данных необходимо отсечь выбросы по 95 персентилю

# Фильтруем данные по значению 95 персентиля

filtered_profile_df = profile_df.loc[profile_df['orders_count']<order_count_95pers].reset_index()

# Проверяем

filtered_profile_df.info()

# Количество отфильтрованных строк
print(f'В результате фильтрации выборка уменьшена на: {profile_df.shape[0] - filtered_profile_df.shape[0]} строк, что составляет {round((profile_df.shape[0] - filtered_profile_df.shape[0]) / profile_df.shape[0] * 100, 1)} %' )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20468 entries, 0 to 20467
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  20468 non-null  int64
#  1   user_id                20468 non-null  object
#  2   first_order            20468 non-null  datetime64[ns]
#  3   last_order             20468 non-null  datetime64[ns]
#  4   orders_count           20468 non-null  int64
#  5   avg_revenue            20468 non-null  float64
#  6   avg_tickets            20468 non-null  float64
#  7   avg_days_between       11776 non-null  float32
#  8   device_type_canonical  20468 non-null  object
#  9   region_name            20468 non-null  object
#  10  service_name           20468 non-null  object
#  11  event_type_main        20468 non-null  object
#  12  is_five                20468 non-null  bool
#  13  is_two                 20468 non-null  bool
# dtypes: bool(2), datetime64[ns](2), float32(1), float64(2), int64(2), object(5)
# memory usage: 1.8+ MB
# В результате фильтрации выборка уменьшена на: 1083 строк, что составляет 5.0 %

# %% [markdown]
# ### Выводы
#
# Таким образом, мы получили профиль пользователей, проанализировали данные на выбросы и аномалии, отфильтровали выбросы.
# Также удалось расчитать средние значения по основным параметрам:
# 1. Всего для исследования будет использоваться: 20 468 пользователь
# 2. Среднее число билетов в заказе: 2.7
# 3. Средняя выручка с одного заказа: 546 руб
# 4. Более 59 % пользователей имеют 2 и более заказов, более 24% имеют 5 и более заказов

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Выше смотришь распределение только по чилу заказов? А другие признаки?

# %% [markdown]
# <div class="alert alert-info"> Я сделал согласно плана задачи. Исследование возвратов пользователей по разным признакам ниже. В условии указано: <b>Чтобы ваше исследование шло оптимальным путём, чётко следуйте изложенным дальше шагам. </b></div>

# %% [markdown]
# ### 4. Исследовательский анализ данных

# %% [markdown]
# Для исследовательского анализа будем использовать отфильтрованный датасет filtered_profile_df

# %% [markdown]
# #### 4.1 Исследование признаков первого заказа и их связи с возвращением на платформу

# %% [markdown]
# Сгруппируем пользователей по признакам:
# 1. По типу их первого мероприятия
# 2. По типу устройства, с которого совершена первая покупка
# 3. По региону проведения мероприятия из первого заказа
# 4. По билетному оператору, продавшему билеты на первый заказ

# %%
# Для расчета долей пользователей по сегментам запишем в переменную total общее число строк в датафрейме

total = filtered_profile_df.shape[0]
print(f'Всего пользователей в датафрейме: {total}')
# Out:
# Всего пользователей в датафрейме: 20468

# %%
# Группируем по типу первого мероприятия и считаем долю пользователей для каждого типа

# Считаем число пользователей для каждого типа мероприятия
first_event_type = filtered_profile_df.groupby('event_type_main')['user_id'].count().reset_index()

# Считаем долю пользователей
for et in first_event_type:
  first_event_type['user_share'] = round(first_event_type['user_id'] / total, 3)


print(first_event_type.sort_values(by='user_share', ascending = False))
# Out:
#   event_type_main  user_id  user_share
# 2        концерты     9198       0.449
# 1          другое     4918       0.240
# 5           театр     4042       0.197
# 4         стендап     1064       0.052
# 3           спорт      747       0.036
# 0        выставки      407       0.020
# 6            ёлки       92       0.004

# %%
# Считаем данные по пользователям по типам устройств
first_device_type = filtered_profile_df.groupby('device_type_canonical')['user_id'].count().reset_index()

# Считаем долю по пользователям по типам устройств
for dt in first_device_type:
  first_device_type['user_share'] = round(first_device_type['user_id'] / total, 2)

print(first_device_type.sort_values(by='user_share', ascending = False))
# Out:
#   device_type_canonical  user_id  user_share
# 1                mobile    16983        0.83
# 0               desktop     3485        0.17

# %%
# Считаем данные по пользователям по регионам
first_region_name = filtered_profile_df.groupby('region_name')['user_id'].count().reset_index()

# Считаем долю пользователей по регионам
for rn in first_region_name:
  first_region_name['user_share'] = round(first_region_name['user_id'] / total, 4)

print(first_region_name.sort_values(by='user_share', ascending = False))
# Out:
#                  region_name  user_id  user_share
# 23        Каменевский регион     6646      0.3247
# 60      Североярская область     3565      0.1742
# 77       Широковская область     1189      0.0581
# 45          Озернинский край      660      0.0322
# 41      Малиновоярский округ      516      0.0252
# ..                       ...      ...         ...
# 17            Залесский край        2      0.0001
# 5          Верхозёрский край        1      0.0000
# 56         Светолесский край        1      0.0000
# 66  Сосноводолинская область        1      0.0000
# 80        Яснопольский округ        1      0.0000
#
# [81 rows x 3 columns]

# %%
# Считаем данные по пользователям по сервисам
first_service_name = filtered_profile_df.groupby('service_name')['user_id'].count().reset_index()

# Считаем долю пользователей по сервисам
for sn in first_region_name:
  first_service_name['user_share'] = round(first_service_name['user_id'] / total, 4)

print(first_service_name.sort_values(by='user_share', ascending = False))
# Out:
#               service_name  user_id  user_share
# 3       Билеты без проблем     4706      0.2299
# 22               Мой билет     2854      0.1394
# 19             Лови билет!     2674      0.1306
# 4            Билеты в руки     2420      0.1182
# 23                 Облачко     2130      0.1041
# 7           Весь в билетах     1225      0.0598
# 20           Лучшие билеты     1125      0.0550
# 24               Прачечная      553      0.0270
# 17            Край билетов      441      0.0215
# 12            Дом культуры      335      0.0164
# 33                  Яблоко      307      0.0150
# 28             Тебе билет!      301      0.0147
# 11  Городской дом культуры      203      0.0099
# 13             За билетом!      199      0.0097
# 21                Мир касс      199      0.0097
# 5              Быстробилет      156      0.0076
# 1              Show_ticket      156      0.0076
# 10          Выступления.ру       94      0.0046
# 8                Восьмёрка       86      0.0042
# 6           Быстрый кассир       54      0.0026
# 0            Crazy ticket!       42      0.0021
# 27                Росбилет       39      0.0019
# 25            Радио ticket       35      0.0017
# 29               Телебилет       29      0.0014
# 26                  Реестр       26      0.0013
# 31            Цвет и билет       20      0.0010
# 32         Шоу начинается!       18      0.0009
# 15              КарандашРУ       14      0.0007
# 16              Кино билет        9      0.0004
# 9                  Вперёд!        7      0.0003
# 2        Билет по телефону        6      0.0003
# 18                  Лимоны        2      0.0001
# 30               Тех билет        2      0.0001
# 14                Зе Бест!        1      0.0000

# %% [markdown]
# По всем признакам можно сделать вывод: доли пользователей распределены не равномерно, есть выраженные точки входа по каждому из признаков.

# %%
# Для каждого признака расчитаем по сегментам долю пользователей, которые совершили 2 и более заказа. Отобразим данные на графиках

# %%
# Считаем число пользователей для каждого типа мероприятия, добавив группировку по наличию признака "2 и более заказов"
first_event_type_2 = filtered_profile_df.groupby(['event_type_main', 'is_two'])['user_id'].count().reset_index()

# Считаем долю с заказами 2 и более по каждому типу. Для этого используем сводную таблицу

pivot_first_event_type_2 = first_event_type_2.pivot_table(
    index='event_type_main',
    columns='is_two',
    values='user_id',
    aggfunc='sum'
)

pivot_first_event_type_2.columns = ['False_count', 'True_count']

pivot_first_event_type_2['total'] = pivot_first_event_type_2['False_count'] + pivot_first_event_type_2['True_count']
pivot_first_event_type_2['true_share'] = (pivot_first_event_type_2['True_count'] / pivot_first_event_type_2['total'] * 100).round(1)

print(pivot_first_event_type_2.sort_values(by='true_share', ascending=False))
# Out:
#                  False_count  True_count  total  true_share
# event_type_main
# выставки                 158         249    407        61.2
# театр                   1651        2391   4042        59.2
# концерты                3936        5262   9198        57.2
# стендап                  457         607   1064        57.0
# другое                  2199        2719   4918        55.3
# ёлки                      45          47     92        51.1
# спорт                    368         379    747        50.7

# %%
# Визуализируем данные на столбчатой диаграмме

pivot_first_event_type_2.sort_values(by='total', ascending=False).plot(kind='bar', y='true_share', legend = False, xlabel = 'Тип мероприятия', ylabel = 'Доля возвратов, %')
plt.show()

# %% [markdown]
# Можно сделать вывод, что по типам мероприятий "Выставки", "Концерты" и "Театры" доля возврата пользователей выше, составляет 60% и более. По другим типам - в диапазоне от 50% до 60%

# %%
# Считаем число пользователей для каждого типа устройств, добавив группировку по наличию признака "2 и более заказов"
first_device_type_2 = filtered_profile_df.groupby(['device_type_canonical', 'is_two'])['user_id'].count().reset_index()

pivot_first_device_type_2 = first_device_type_2.pivot_table(
    index='device_type_canonical',
    columns='is_two',
    values='user_id',
    aggfunc='sum'
)

pivot_first_device_type_2.columns = ['False_count', 'True_count']

pivot_first_device_type_2['total'] = pivot_first_device_type_2['False_count'] + pivot_first_device_type_2['True_count']
pivot_first_device_type_2['true_share'] = (pivot_first_device_type_2['True_count'] / pivot_first_device_type_2['total'] * 100).round(1)

print(pivot_first_device_type_2)
# Out:
#                        False_count  True_count  total  true_share
# device_type_canonical
# desktop                       1409        2076   3485        59.6
# mobile                        7405        9578  16983        56.4

# %%
# Визуализируем данные на столбчатой диаграмме

pivot_first_device_type_2.plot(kind='bar', y='true_share', legend = False, xlabel = 'Тип устройства', ylabel = 'Доля возвратов, %')
plt.show()

# %% [markdown]
# Можно сделать вывод, что по всем типам устройств - доля возвратов ~60% - одного уровня, и не имеет выраженного выделения, но доля возвратов десктопных устройств чуть выше, чем с мобильных

# %%
# Считаем число пользователей для каждого региона, добавив группировку по наличию признака "2 и более заказов"
first_region_name_2 = filtered_profile_df.groupby(['region_name', 'is_two'])['user_id'].count().reset_index()

pivot_first_region_name_2 = first_region_name_2.pivot_table(
    index='region_name',
    columns='is_two',
    values='user_id',
    aggfunc='sum'
)

pivot_first_region_name_2.columns = ['False_count', 'True_count']

pivot_first_region_name_2['total'] = pivot_first_region_name_2['False_count'] + pivot_first_region_name_2['True_count']
pivot_first_region_name_2['true_share'] = (pivot_first_region_name_2['True_count'] / pivot_first_region_name_2['total'] * 100).round(1)

print(pivot_first_region_name_2.sort_values(by='total', ascending=False).head(10))
# Out:
#                       False_count  True_count   total  true_share
# region_name
# Каменевский регион         2806.0      3840.0  6646.0        57.8
# Североярская область       1442.0      2123.0  3565.0        59.6
# Широковская область         467.0       722.0  1189.0        60.7
# Озернинский край            327.0       333.0   660.0        50.5
# Малиновоярский округ        245.0       271.0   516.0        52.5
# Светополянский округ        167.0       274.0   441.0        62.1
# Травяная область            187.0       249.0   436.0        57.1
# Шанырский регион            160.0       265.0   425.0        62.4
# Речиновская область         172.0       252.0   424.0        59.4
# Яблоневская область         172.0       225.0   397.0        56.7

# %%
pivot_first_region_name_2.sort_values(by='total', ascending=False).head(10).plot(kind='bar', y='true_share', legend = False, xlabel = 'Регион', ylabel = 'Доля возвратов, %')
plt.show()

# %% [markdown]
# Для регионов выведены топ-10 сегментов по числу пользователей в каждом. Доля возвратов колеблется от 57% до 66%. Можно сделать вывод, что нет региона с ярко выраженным высоким % возвратов на сервис, и % возврата находится в двух диапазонах: 50-60% и 60-70% (по 5 регионов в каждом из них). Самый высокий % возврата - в Шанырском округе - 66.4%

# %%
# Считаем число пользователей для каждого билетного оператора, добавив группировку по наличию признака "2 и более заказов"
first_service_name_2 = filtered_profile_df.groupby(['service_name', 'is_two'])['user_id'].count().reset_index()

pivot_first_service_name_2 = first_service_name_2.pivot_table(
    index='service_name',
    columns='is_two',
    values='user_id',
    aggfunc='sum'
)

pivot_first_service_name_2.columns = ['False_count', 'True_count']

pivot_first_service_name_2['total'] = pivot_first_service_name_2['False_count'] + pivot_first_service_name_2['True_count']
pivot_first_service_name_2['true_share'] = (pivot_first_service_name_2['True_count'] / pivot_first_service_name_2['total'] * 100).round(1)

print(pivot_first_service_name_2.sort_values(by='total', ascending=False).head(10))
# Out:
#                     False_count  True_count   total  true_share
# service_name
# Билеты без проблем       2078.0      2628.0  4706.0        55.8
# Мой билет                1253.0      1601.0  2854.0        56.1
# Лови билет!              1155.0      1519.0  2674.0        56.8
# Билеты в руки            1007.0      1413.0  2420.0        58.4
# Облачко                   913.0      1217.0  2130.0        57.1
# Весь в билетах            516.0       709.0  1225.0        57.9
# Лучшие билеты             488.0       637.0  1125.0        56.6
# Прачечная                 232.0       321.0   553.0        58.0
# Край билетов              168.0       273.0   441.0        61.9
# Дом культуры              136.0       199.0   335.0        59.4

# %%
pivot_first_service_name_2.sort_values(by='total', ascending=False).head(10).plot(kind='bar', y='true_share', legend = False, xlabel = 'Билетный сервис', ylabel = 'Доля возвратов, %')

plt.show()

# %% [markdown]
# Для билетных сервисов выведены топ-10 сегментов по числу пользователей в каждом. Доля возвратов колеблется от 58% до 64%. Можно сделать вывод, что нет сервиса с ярко выраженным высоким % возвратов на сервис, и % возврата находится на том же уровне, что и для устройств, и типов мероприятий и регионов. Самое высокое значение возвратов у сервиса "Край билетов" - 63.9%

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Опять же, было бы не лишним дать понятное название подразделу и добавить пояснение к шагу.
#
#
# * В случае вывода неполного набора сегментов стоит указать, какой процент от выборки они составляют, чтобы было понимание, насколько большая часть данных осталась за пределами нашего обзора.
#
#
# * На графиках сегменты было бы логичнее отсортировать от большего к меньшему, поскольку большие сегменты представляют для нас больший интерес.
#
#
# * Также было бы неплохо добавить на графики линию среднего значения, чтобы было удобно сравнивать, какие сегменты и насколько отличаются от общего показателя по выборке. Это можно сделать с помощью `plt.axvline`, потребуется также добавить легенду.
#
#
# * Выводы лучше подкреплять конкретными значениями (в данном случае количеством и долей), чтобы явно отразить, насколько велики эффекты, о которых мы говорим.
#
# </div>

# %% [markdown]
# ##### Гипотеза 1:
# Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
#
# ##### Результат исследования:
# Наше исследование опровергает данную гипотезу: число пользователей, которые возвращаются на Яндекс Афишу - для типа "концерты"  выше (60.2% возвратов), чем "спорт" (53.4% возвратов)

# %% [markdown]
# ##### Гипотеза 2:
#
# В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ##### Результат исследования:
#
# Наше исследование опровергает данную гипотезу. В регионах с наибольшим числом посетителей мероприятий % возврата немного ниже, чем в менее активных по числу пользователей регионов.
# Топ-2 региона по числу посетителей имеют 60.2% и 62.5% возвратов, а Топ-8 и Топ-9 (регионы из первой десятки по числу посетителей) - 66.4% и 61.8%

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# По второй гипотезе можно сопоставить объем выборки с полученными результатом

# %% [markdown]
# #### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа

# %%
# Для построения гистограммы распределения средней выручки с билета необходимо добавить новое поле: 
# avg_revenue_rub - средняя выручка с билета, в датафрейм filtered_profile_df и расчитать его

filtered_profile_df['avg_revenue_rub'] = round(filtered_profile_df['avg_revenue'] / filtered_profile_df['avg_tickets'], 1)

# Проверяем

filtered_profile_df.info()
filtered_profile_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20468 entries, 0 to 20467
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  20468 non-null  int64
#  1   user_id                20468 non-null  object
#  2   first_order            20468 non-null  datetime64[ns]
#  3   last_order             20468 non-null  datetime64[ns]
#  4   orders_count           20468 non-null  int64
#  5   avg_revenue            20468 non-null  float64
#  6   avg_tickets            20468 non-null  float64
#  7   avg_days_between       11776 non-null  float32
#  8   device_type_canonical  20468 non-null  object
#  9   region_name            20468 non-null  object
#  10  service_name           20468 non-null  object
#  11  event_type_main        20468 non-null  object
#  12  is_five                20468 non-null  bool
#  13  is_two                 20468 non-null  bool
#  14  avg_revenue_rub        20468 non-null  float64
# dtypes: bool(2), datetime64[ns](2), float32(1), float64(3), int64(2), object(5)
# memory usage: 2.0+ MB
#    index          user_id first_order last_order  orders_count  avg_revenue  \
# 0      0  0002849b70a3ce2  2024-08-20 2024-08-20             1  1521.940000
# 1      1  0005ca5e93f2cf4  2024-07-23 2024-10-06             2   774.010000
# 2      2  000898990054619  2024-07-13 2024-10-23             3   767.213333
# 3      3  00096d1f542ab2b  2024-08-15 2024-08-15             1   917.830000
# 4      4  000a55a418c128c  2024-09-29 2024-10-15             2    61.310000
#
#    avg_tickets  avg_days_between device_type_canonical           region_name  \
# 0     4.000000               NaN                mobile    Каменевский регион
# 1     3.000000              75.0                mobile    Каменевский регион
# 2     2.666667              51.0                mobile  Североярская область
# 3     4.000000               NaN               desktop    Каменевский регион
# 4     1.500000              16.0                mobile      Поленовский край
#
#     service_name event_type_main  is_five  is_two  avg_revenue_rub
# 0   Край билетов           театр    False   False            380.5
# 1      Мой билет        выставки    False    True            258.0
# 2    Лови билет!          другое    False    True            287.7
# 3   Край билетов           театр    False   False            229.5
# 4  Лучшие билеты           театр    False    True             40.9

# %%
# Строим гистограмму распределения средней выручки с билета
# Создаём фигуру графика
plt.figure(figsize=(10, 4))

# Строим гистограммы для каждого значения is_two
for i in filtered_profile_df['is_two'].unique():
    # Фильтруем данные по значению столбца is_two
    filtered_profile_df.loc[filtered_profile_df['is_two'] == i, 'avg_revenue_rub'].plot(
        kind='hist',
        density=True,
        bins=25,
        alpha=0.7,
        label=f'{i}',
        legend=True
    )

# Настраиваем внешний вид графика и выводим его на экран
plt.title(f'Сравнение распределение выручки с билета в зависимости от признака "is_two"')
plt.xlabel('Выручка с билета')
plt.ylabel('Плотность вероятности')
plt.legend(title='Значение is_two')
plt.show()

# %% [markdown]
# Из гистограммы распределения видно, что наибольшее число пользователей совершивших один заказ находится в диапазонах выручки с билета до 70 рублей (одна корзина на графике ~ 70 руб), после идет значительное снижение. У пользователей совершивших 2 и более заказов - ниже доля пользователей в заказах до 70 руб с билета, выше доля в диапазонах выручки 70-400 руб с билета, снижение более плавное. В заказах стоимостью 400 с билета и выше - разовых заказов больше.

# %%
# Для сравнения выручки с заказа у пользователей с 2-4 билетам с 5 и выше - отфильтруем наш датафрейм по is_two = True и 
# построим гистограмму распределения по признаку is_five

filtered_profile_df_2_only = filtered_profile_df.loc[filtered_profile_df['is_two'] == True]

# Проверяем

filtered_profile_df_2_only.info()
filtered_profile_df_2_only.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11654 entries, 1 to 20465
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  11654 non-null  int64
#  1   user_id                11654 non-null  object
#  2   first_order            11654 non-null  datetime64[ns]
#  3   last_order             11654 non-null  datetime64[ns]
#  4   orders_count           11654 non-null  int64
#  5   avg_revenue            11654 non-null  float64
#  6   avg_tickets            11654 non-null  float64
#  7   avg_days_between       11654 non-null  float32
#  8   device_type_canonical  11654 non-null  object
#  9   region_name            11654 non-null  object
#  10  service_name           11654 non-null  object
#  11  event_type_main        11654 non-null  object
#  12  is_five                11654 non-null  bool
#  13  is_two                 11654 non-null  bool
#  14  avg_revenue_rub        11654 non-null  float64
# dtypes: bool(2), datetime64[ns](2), float32(1), float64(3), int64(2), object(5)
# memory usage: 1.2+ MB
#    index          user_id first_order last_order  orders_count  avg_revenue  \
# 1      1  0005ca5e93f2cf4  2024-07-23 2024-10-06             2   774.010000
# 2      2  000898990054619  2024-07-13 2024-10-23             3   767.213333
# 4      4  000a55a418c128c  2024-09-29 2024-10-15             2    61.310000
# 5      5  000cf0659a9f40f  2024-06-20 2024-06-21             5  1137.526000
# 6      6  00147c9209d45d3  2024-06-25 2024-06-25             2   352.945000
#
#    avg_tickets  avg_days_between device_type_canonical           region_name  \
# 1     3.000000             75.00                mobile    Каменевский регион
# 2     2.666667             51.00                mobile  Североярская область
# 4     1.500000             16.00                mobile      Поленовский край
# 5     3.200000              0.25                mobile   Широковская область
# 6     1.500000              0.00                mobile    Каменевский регион
#
#     service_name event_type_main  is_five  is_two  avg_revenue_rub
# 1      Мой билет        выставки    False    True            258.0
# 2    Лови билет!          другое    False    True            287.7
# 4  Лучшие билеты           театр    False    True             40.9
# 5    Лови билет!        концерты     True    True            355.5
# 6        Облачко        концерты    False    True            235.3

# %%
# Строим гистограмму распределения средней выручки с заказа
# Создаём фигуру графика
plt.figure(figsize=(10, 4))

# Строим гистограммы для каждого значения is_five
for i in filtered_profile_df_2_only['is_five'].unique():
    # Фильтруем данные по значению столбца is_two
    filtered_profile_df_2_only.loc[filtered_profile_df_2_only['is_five'] == i, 'avg_revenue'].plot(
        kind='hist',
        density=True,
        bins=20,
        alpha=0.7,
        label=f'{i}',
        legend=True
    )

# Настраиваем внешний вид графика и выводим его на экран
plt.title(f'Сравнение распределение выручки с заказа в зависимости от признака "is_five"')
plt.xlabel('Выручка с заказа')
plt.ylabel('Плотность вероятности')
plt.legend(title='Значение is_five')
plt.show()

# %% [markdown]
# Между группами 2-4 и 5+ заказов на графике видно различие: группа 2-4 заказа имеет максимальную долю в заказах до 500р с плавным снижением. Группа 5+ - имеет выручку с заказа выше в диапазонах от 300 до 800 руб, сначала распределение повышается, потом снижается, имеет пик в диапазоне 500-600 руб. Можно сделать вывод, что у пользователей с 5+ заказами выручка с заказа выше, чем у тех, кто сделал 2-4 заказа.
#
# Но в диапазонах выручки выше 1000 руб - больше доля группы 2-4 заказа.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
#
#
# * Плюс за грамотное оформление графиков - заголовок, подписи осей, легенда, поправка на размер выборки (`density`). По выводам тоже все верно подмечено!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
#
#
#
# * Чтобы удобно было сопоставлять доли пользователей по диапазонам цен, можно настроить единый размер бинов (`bins = 20` фиксирует количество бинов, но размер между сегментами будет отличаться, поскольку диапазон значений у них разный). Для этого в `bins` можно передать границы для формирования бинов с шагом: `bins = range(min_value, max_value+1, 50)`, максимальное и минимальное значения при этом определяем на всей выборке, а не отдельно для каждого сегмента.
#
# </div>

# %%
# Разобьем пользователей в датафрейме filtered_profile_df на сегменты в зависимости от среднего числа билетов в заказе
# Запишем сегмент в новое поле ticket_seg

# Напишем функцию для сегментации
def ticket_segments(row):
    if (row['avg_tickets'] >= 1) & (row['avg_tickets'] < 2):
        return "1-2 seg"
    elif (row['avg_tickets'] >= 2) & (row['avg_tickets'] < 3):
        return "2-3 seg"
    elif (row['avg_tickets'] >= 3) & (row['avg_tickets'] < 5):
        return "3-5 seg"
    elif row['avg_tickets'] >= 5:
        return "5+ seg"

# Применим функцию для нашего датафрейма
filtered_profile_df['ticket_seg'] = filtered_profile_df.apply(ticket_segments, axis=1)

# Проверяем

filtered_profile_df.info()
filtered_profile_df['ticket_seg'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20468 entries, 0 to 20467
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  20468 non-null  int64
#  1   user_id                20468 non-null  object
#  2   first_order            20468 non-null  datetime64[ns]
#  3   last_order             20468 non-null  datetime64[ns]
#  4   orders_count           20468 non-null  int64
#  5   avg_revenue            20468 non-null  float64
#  6   avg_tickets            20468 non-null  float64
#  7   avg_days_between       11776 non-null  float32
#  8   device_type_canonical  20468 non-null  object
#  9   region_name            20468 non-null  object
#  10  service_name           20468 non-null  object
#  11  event_type_main        20468 non-null  object
#  12  is_five                20468 non-null  bool
#  13  is_two                 20468 non-null  bool
#  14  avg_revenue_rub        20468 non-null  float64
#  15  ticket_seg             20468 non-null  object
# dtypes: bool(2), datetime64[ns](2), float32(1), float64(3), int64(2), object(6)
# memory usage: 2.1+ MB
# array(['3-5 seg', '2-3 seg', '1-2 seg', '5+ seg'], dtype=object)

# %%
# Теперь сгруппируем необходимые для анализа данные в новый датафрейм

profile_df_ticket_seg = filtered_profile_df[['user_id', 
                                             'is_two', 
                                             'ticket_seg']].groupby(['ticket_seg', 
                                                                     'is_two'])['user_id'].count().reset_index()

# Проверяем

profile_df_ticket_seg
# Out:
#   ticket_seg  is_two  user_id
# 0    1-2 seg   False     1260
# 1    1-2 seg    True     1014
# 2    2-3 seg   False     2677
# 3    2-3 seg    True     6243
# 4    3-5 seg   False     4426
# 5    3-5 seg    True     4385
# 6     5+ seg   False      451
# 7     5+ seg    True       12

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# В единственной или последней строке ячейки кода Юпитера, метод print() не обязателен, в отличии от тренажера

# %% [markdown]
# <div class="alert alert-info"> Принято!</div>

# %%
# Посчитаем долю повторных покупок по каждому сегменту, соберем данные в сводную таблицу

pivot_profile_df_ticket_seg = profile_df_ticket_seg.pivot_table(
    index='ticket_seg',
    columns='is_two',
    values='user_id',
    aggfunc='sum'
)

pivot_profile_df_ticket_seg.columns = ['False_count', 'True_count']

pivot_profile_df_ticket_seg['total'] = pivot_profile_df_ticket_seg['False_count'] + pivot_profile_df_ticket_seg['True_count']
pivot_profile_df_ticket_seg['true_share'] = (pivot_profile_df_ticket_seg['True_count'] / pivot_profile_df_ticket_seg['total'] * 100).round(1)

pivot_profile_df_ticket_seg.sort_values(by='total', ascending=False)
# Out:
#             False_count  True_count  total  true_share
# ticket_seg
# 2-3 seg            2677        6243   8920        70.0
# 3-5 seg            4426        4385   8811        49.8
# 1-2 seg            1260        1014   2274        44.6
# 5+ seg              451          12    463         2.6

# %%
# Выведем визуализацию по сегментам

pivot_profile_df_ticket_seg.sort_values(by='total', ascending=False).plot(kind='bar', y='true_share', legend = False, xlabel = 'Сегмент по количеству билетов', ylabel = 'Доля возвратов, %')
plt.show()

# %% [markdown]
# Можно сделать вывод, что в сегменте 2-3 билета на заказ - наиболее высокая доля возвратов - 71.2%. Напротив, в сегменте с 5+ билетами - доля возвратов низкая, 18.9%
#
# С точки зрения распределения пользователей по сегментам - пользователи сконцентрированы в двух сегментах - 2-3 билета и 3-5 билетов

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно чуть развить вывод — предположить, почему пользователи, покупающие 2–3 билета, возвращаются чаще. Например, это могут быть небольшие компании или семьи, которые чаще ходят на мероприятия вместе, а значит, лояльность у них выше. А вот пользователи с 5+ билетами, вероятно, совершают разовые групповые покупки (например, для организации или класса), поэтому возвращаются реже

# %% [markdown]
# #### 4.3 Исследование временных характеристик первого заказа и их влияния на повторные покупки

# %%
# Проведем анализ дня недели первой покупки у каждого пользователя. Добавим новое поле в датафрейм: first_purchase_day

filtered_profile_df['first_purchase_day'] = filtered_profile_df['first_order'].dt.strftime('%A')

# Проверяем

filtered_profile_df['first_purchase_day'].unique()
# Out:
# array(['Tuesday', 'Saturday', 'Thursday', 'Sunday', 'Monday', 'Wednesday',
#        'Friday'], dtype=object)

# %%
# Для необходимого анализа соберем отдельный датафрейм

filtered_profile_df_dow = filtered_profile_df[['user_id', 'first_purchase_day', 'is_two']].groupby(['first_purchase_day', 'is_two'])['user_id'].count().reset_index()

# Проверяем

print(filtered_profile_df_dow)
# Out:
#    first_purchase_day  is_two  user_id
# 0              Friday   False     1372
# 1              Friday    True     1745
# 2              Monday   False     1161
# 3              Monday    True     1602
# 4            Saturday   False     1294
# 5            Saturday    True     1783
# 6              Sunday   False     1147
# 7              Sunday    True     1447
# 8            Thursday   False     1333
# 9            Thursday    True     1660
# 10            Tuesday   False     1286
# 11            Tuesday    True     1703
# 12          Wednesday   False     1221
# 13          Wednesday    True     1714

# %%
# Для подсчета повторных покупок соберем сводную таблицу и выведем визуализацию повторных покупок по дню недели

pivot_filtered_profile_df_dow = filtered_profile_df_dow.pivot_table(
    index='first_purchase_day',
    columns='is_two',
    values='user_id',
    aggfunc='sum'
)

pivot_filtered_profile_df_dow.columns = ['False_count', 'True_count']

pivot_filtered_profile_df_dow['total'] = pivot_filtered_profile_df_dow['False_count'] + pivot_filtered_profile_df_dow['True_count']
pivot_filtered_profile_df_dow['true_share'] = (pivot_filtered_profile_df_dow['True_count'] / pivot_filtered_profile_df_dow['total'] * 100).round(1)

print(pivot_filtered_profile_df_dow.sort_values(by='total', ascending=False))
# Out:
#                     False_count  True_count  total  true_share
# first_purchase_day
# Friday                     1372        1745   3117        56.0
# Saturday                   1294        1783   3077        57.9
# Thursday                   1333        1660   2993        55.5
# Tuesday                    1286        1703   2989        57.0
# Wednesday                  1221        1714   2935        58.4
# Monday                     1161        1602   2763        58.0
# Sunday                     1147        1447   2594        55.8

# %%
# Выведем визуализацию по дням недели, отсортируем по числу покупателей по убыванию

pivot_filtered_profile_df_dow.sort_values(by='total', ascending=False).plot(kind='bar', y='true_share', legend = False, xlabel = 'Распределение покупателей по дням недели', ylabel = 'Доля возвратов, %')
plt.show()

# %% [markdown]
# Вывод: дни недели не имеют ярко выраженного различия, однако, видно, что в воскресенья и понедельники доля первых покупок ниже, чем в остальные дни, кооторые распределились равномерно. Доля возвратов покупателей колеблется от 58% до 61% и также не имеет ярко выделенной зависимости

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Когда планируют досуг, но возвращаемость остаётся примерно одинаковой — это говорит о том, что день недели первой покупки не влияет на лояльность, а повторное использование сервиса определяется скорее качеством опыта и интересом к мероприятиям

# %%
# Рассчитаем показатель Среднее время между покупками для двух сегментов пользователей: совершившие 2-4 покупки и 5+ покупок
# Пользователи, у которых признак is_two = True, is_five = False - совершили от 2 до 4 покупок, пользователи у которых 
# is_two = True, is_five = True - совершили 5+ покупок

filtered_profile_df.loc[filtered_profile_df['is_two']==True].groupby(['is_two', 'is_five'])['avg_days_between'].mean().reset_index()
# Out:
#    is_two  is_five  avg_days_between
# 0    True    False         22.972740
# 1    True     True         13.444708

# %% [markdown]
# Вывод: чем больше заказов сделал пользователь, тем ниже среднее значение времени между заказами

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
# <b>Отлично ✅:</b> По расчетам все верно!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# <b>Рекомендации💡:</b>  Важно иметь в виду, что среднее значение довольно сильно зависит от характера распределения, если есть какие-то сильные выбросы, они могут утянуть среднее значение вверх, хотя основаня масса значений будет гораздо ниже. Поэтому здесь важно было бы построить в том числе гистограммы, наложить их друг на друга (как мы это делали при сравнении выручки), чтобы видеть всю картину в данных.
#
# </div>

# %% [markdown]
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя

# %%
# Для расчета коэффициента хи-квадрат импортируем нужные библиотеки
from phik import phik_matrix

# %%
filtered_profile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20468 entries, 0 to 20467
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  20468 non-null  int64
#  1   user_id                20468 non-null  object
#  2   first_order            20468 non-null  datetime64[ns]
#  3   last_order             20468 non-null  datetime64[ns]
#  4   orders_count           20468 non-null  int64
#  5   avg_revenue            20468 non-null  float64
#  6   avg_tickets            20468 non-null  float64
#  7   avg_days_between       11776 non-null  float32
#  8   device_type_canonical  20468 non-null  object
#  9   region_name            20468 non-null  object
#  10  service_name           20468 non-null  object
#  11  event_type_main        20468 non-null  object
#  12  is_five                20468 non-null  bool
#  13  is_two                 20468 non-null  bool
#  14  avg_revenue_rub        20468 non-null  float64
#  15  ticket_seg             20468 non-null  object
#  16  first_purchase_day     20468 non-null  object
# dtypes: bool(2), datetime64[ns](2), float32(1), float64(3), int64(2), object(7)
# memory usage: 2.3+ MB

# %%
# Построим корелляционную матрицу для нашего датафрейма filtered_profile_df

# Отфильтруем датафрейм с признаками профиля пользователя
phik_profile_df = filtered_profile_df[['avg_tickets', 'avg_revenue_rub','orders_count', 'avg_days_between', 'device_type_canonical', 'region_name', 'service_name', 'event_type_main']]

correlation_matrix = phik_profile_df.phik_matrix(interval_cols=['avg_days_between', 'avg_revenue_rub'])

print(correlation_matrix)
# Out:
#                        avg_tickets  avg_revenue_rub  orders_count  \
# avg_tickets               1.000000         0.000000      0.989281
# avg_revenue_rub           0.000000         1.000000      0.175882
# orders_count              0.989281         0.175882      1.000000
# avg_days_between          0.127453         0.051344      0.498717
# device_type_canonical     0.098802         0.041832      0.036153
# region_name               0.000000         0.379845      0.000000
# service_name              0.000000         0.412552      0.000000
# event_type_main           0.089621         0.323281      0.037413
#
#                        avg_days_between  device_type_canonical  region_name  \
# avg_tickets                    0.127453               0.098802     0.000000
# avg_revenue_rub                0.051344               0.041832     0.379845
# orders_count                   0.498717               0.036153     0.000000
# avg_days_between               1.000000               0.024343     0.118757
# device_type_canonical          0.024343               1.000000     0.111605
# region_name                    0.118757               0.111605     1.000000
# service_name                   0.050630               0.080346     0.699020
# event_type_main                0.054145               0.063095     0.515460
#
#                        service_name  event_type_main
# avg_tickets                0.000000         0.089621
# avg_revenue_rub            0.412552         0.323281
# orders_count               0.000000         0.037413
# avg_days_between           0.050630         0.054145
# device_type_canonical      0.080346         0.063095
# region_name                0.699020         0.515460
# service_name               1.000000         0.586101
# event_type_main            0.586101         1.000000

# %%
# Разделим значение orders_count на сегменты и присвоим их в новое поле total_orders_seg

# Напишем функцию для сегментации
def order_segments(row):
    if row['orders_count'] == 1:
        return "1 order seg"
    elif (row['avg_tickets'] >= 2) & (row['avg_tickets'] <= 4):
        return "2-4 order seg"
    elif row['avg_tickets'] >= 5:
        return "5+ order seg"

# Применим функцию для нашего датафрейма
filtered_profile_df['total_orders_seg'] = filtered_profile_df.apply(order_segments, axis=1)

# Проверяем

filtered_profile_df.groupby(['total_orders_seg'])['user_id'].count()
# Out:
# total_orders_seg
# 1 order seg       8814
# 2-4 order seg    10425
# 5+ order seg        12
# Name: user_id, dtype: int64

# %%
# Посмотрим матрицу заново

# Отфильтруем датафрейм с признаками профиля пользователя - вместо числа заказов добавим поле total_orders_seg
phik_profile_df = filtered_profile_df[['avg_tickets', 'total_orders_seg', 'avg_revenue_rub', 'avg_days_between', 'device_type_canonical', 'region_name', 'service_name', 'event_type_main']]

correlation_matrix = phik_profile_df.phik_matrix(interval_cols=['avg_days_between', 'avg_revenue_rub'])

print(correlation_matrix)
# Out:
#                        avg_tickets  total_orders_seg  avg_revenue_rub  \
# avg_tickets               1.000000          0.770370         0.000000
# total_orders_seg          0.770370          1.000000         0.270744
# avg_revenue_rub           0.000000          0.270744         1.000000
# avg_days_between          0.127453          0.124596         0.051344
# device_type_canonical     0.098802          0.016606         0.041832
# region_name               0.000000          0.080154         0.379845
# service_name              0.000000          0.050012         0.412552
# event_type_main           0.089621          0.038434         0.323281
#
#                        avg_days_between  device_type_canonical  region_name  \
# avg_tickets                    0.127453               0.098802     0.000000
# total_orders_seg               0.124596               0.016606     0.080154
# avg_revenue_rub                0.051344               0.041832     0.379845
# avg_days_between               1.000000               0.024343     0.118757
# device_type_canonical          0.024343               1.000000     0.111605
# region_name                    0.118757               0.111605     1.000000
# service_name                   0.050630               0.080346     0.699020
# event_type_main                0.054145               0.063095     0.515460
#
#                        service_name  event_type_main
# avg_tickets                0.000000         0.089621
# total_orders_seg           0.050012         0.038434
# avg_revenue_rub            0.412552         0.323281
# avg_days_between           0.050630         0.054145
# device_type_canonical      0.080346         0.063095
# region_name                0.699020         0.515460
# service_name               1.000000         0.586101
# event_type_main            0.586101         1.000000

# %%
# Построим тепловую карту для визуализации коэффициента

sns.heatmap(data=correlation_matrix, annot=True, fmt='.2f', linewidths=0.5, cmap='coolwarm')

plt.title('Корелляционная матрица')
plt.show()

# %% [markdown]
# Вывод: с количеством заказа высокий уровень связи показывает признак Среднее число билетов в заказе. Все остальные признаки - не связаны или показывают слабую связь

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Не забываем написать пояснение к шагу.
#
#
# * Мы не получили для `orders_count` нулевых корреляций, но ради эксперимента все же можно было бы проверить, насколько сильно поменяются оценки, если сбалансировать разбиение на интервалы.
#
#
# * В выводах Было бы неплохо сделать более явный акцент на том, что поведение клиентов во времени и количество билетов важнее для объяснения повторных покупок, чем их демография или первый выбор сервиса.
#
# * Посмотреть графики зависимостей по сегментам

# %% [markdown]
# ### Вывод

# %% [markdown]
# В работу была принята выборка данных о заказах пользователей Яндекс Афиши. Исходная выборка содержала данные о 290 611 заказах по 14 показателям. В рамках подготовки данных - стоимость заказов была переведена в единую валюту - Рубль РФ с помощью истории изменения курса.
#
# Далее было проведено исследование на пропуски и аномальные данные. Данные были приведены к нужному формату, у части полей была изменена размерность для оптимальной работы с памятью. Также были обнаружены выбросы в поле Выручка с заказа, было принято решение провести фильтрацию по 99 персентилю. Всего было отфильтровано 3.1% данных.
#
# Далее был построен профиль пользователей: всего в выборке присутствовали данные по 21 694 пользователям, которые совершали данные заказы.
# Средняя выручка с заказа по всей выборке: 550 рублей. 61.67% пользователей осуществили 2 и более заказов, 28.87% - 5 и более.
# Среднее число дней между заказами у пользователей с 2 и более заказами: 15.9
#
# Следующим шагом были отфильтрованы аномальные выбосы в поле числа заказов на 1 пользователя, в результате этой операции выборка сократилась на 3.1 %
#
# Из анализа признаков по заказам видно, что пользователи, сделавшие заказы на Выставки, Концерты и Театры охотнее возвращались на платформу (более 60% возвратов). Также чаще всего возвращались на платформу пользователи Шанырского округа. Вид устройства первого заказа не оказал явного влияния на % возврата.
#
# Также возвраты пользователей связаны с выручкой на билет: пользователи, тратившие менее 100 руб в расчете на билет реже возвращались на платформу, чем те пользователи, которые тратили 200-400 рублей. Также выраженным признаком возврата на платформу является сегмент 2-3 билета, что можно связать с походами на мероприятия с семьей и друзьями: такие пользователи возвращались на платформу более, чем в 70% случаев.
#
# День недели не оказал выраженного влияния на возвраты, однако можно заметить, что пользователи менее активно покупали билеты в воскресенья и понедельники. Также на число заказов на пользователя сильное воздействие оказывал признак количества билетов на пользователя: коэффициент корелляции составил 0.9

# %% [markdown]
# ### Рекомендации
#
# Исходя из проведенного анализа, можно порекомендовать усилить маркетинговую активность в воскресенья и понедельники, чтобы повысиить активность пользователей.
# Также стоит обратить внимание и повысить активность в сегменте покупок категории Спорт. Неплохо было бы проработать программу лояльности для возврата пользователей, которые покупали 5 и более билетов, тк % возврата среди них самый низкий. Возможно, это связано с эпизодическими покупками на большую компанию

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С задачей справились! Все ключевые моменты отражены, что позволяет быстро ознакомиться с процессом работы и результатом, не вдаваясь в технический детали. Здорово, что завершаешь проект рекомендациями, основанные на выявленных закономерностях. Предложенные рекомендации логично следуют из анализа и могут быть непосредственно реализованы в маркетинговых стратегиях подогревания и удержания.
#
# </div>

# %% [markdown]
# ### Удаленный репозиторий
#
# https://github.com/mymensk/yandex_praktikum_2_module_final

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Важно убрать чувствительные данные (логины, пароли). В начале проекта об этом описал
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Можно еще добавить информацию в readme.md, где указать ключевые моменты проекта. Или зафиксировать цели и полученные выводы.

# %% [markdown]
# <div class="alert alert-info"> Исправил, возможно не все, но в дальшейнем какие то вещи обязательно буду использовать. Спасибо</div>
